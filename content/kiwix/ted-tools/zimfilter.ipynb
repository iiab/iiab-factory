# %% [markdown]
# ## Modifying ZIM Files
#
# #### The Larger Picture
# * Kiwix scrapes many useful sources, but sometimes the chunks are too big for IIAB.
# * Using the zimdump program, the highly compressed ZIM files can be flattened into a file tree, modified, and then re-packaged as a ZIM file.
# * This Notebook has a collection of tools which help in the above process.

# %% [markdown]
# #### How to Use this notebook
# * There are install steps that only need to happen once. The cells containing these steps are set to "Raw" in the right most dropdown so that they do not execute automatically each time the notebook starts.
# * The following bash script successfully installed zimtools on Ubuntu 20.04.It only needs to be run once. I think it's easier to do it from the command line, with tab completion. In a terminal, do the following:
#
# ```
# cd /opt/iiab/iiab-factory/content/kiwix/generic/
# sudo ./install-zim-tools.sh
# ```

# %% [markdown]
# * **Some conventions**: Jupyter does not want to run as root. We will create a file structure that exists in the users home directory -- so the application will be able to write all the files it needs to function.
# ```
# <PREFIX>
# ├── new-zim
# ├── tree
# ├── working
# └── zim-src
# ```
# In general terms, this program will dump the zim data into "tree", modify it, gather additional data into "working"
# , and create a ZIM file in "new_zim"
# * For testing purposes, the user will need to link from the server's document root to her home directory (so that the nginx http server in IIAB will serve the candidate in "tree):
#
# ```
# cd
# mkdir -p zimtest
# ln -s /home/<user name>/zimtest /library/www/html/zimtest
# ```

# %% [markdown]
# #### Installation Notes to myself
# * Installing on Windows 10 insider preview WSL2. Used https://towardsdatascience.com/configuring-jupyter-notebook-in-windows-subsystem-linux-wsl2-c757893e9d69.
# * First tried installing miniconda, and then installing jupyterlab with it.
# * Wanted VIM bindings to edit cells, but jupyterlab version installed by conda was too old for jupyter-vim extenion. Wound up deleting old version with conda, and used pip to install both.
# * Jupyterlab seems to make the current directory its root. I created a notebook directory, and aways start jupyter lab from my home directiry
# * Discovered that I could enable writing by non-root group in the iiab-factory repo, and continue to use git for version control. Needed to make symbolic link from ~/miniconda to iiab-factory.
# * Reminder: Start jupyterlab in console via "jupyter lab --no-browser", and then pasteing the html link displayed into my browser.

# %% [markdown]
# #### Declare input and output
# * The ZIM file names tend to be long and hard to remember. The PROJECT_NAME, initialized below, is used to create path names. All of the output of the zimdump program is placed in \<home\>/zimtest/\<PROJECT_NAME\>/tree. All if the intermediate downloads, and data, are placed in \<home\>/zimtest/\<PROJECT_NAME\>/working. If you use the IIAB Admin Console to download ZIMS, you will find them in /library/zims/content/.

# %%
# -*- coding: utf-8 -*-
import os,sys
import json
import youtube_dl
import pprint as pprint

# Declare a short project name (ZIM files are often long strings
#PROJECT_NAME = 'ted-kiwix'
PROJECT_NAME = 'teded'
PREFIX = os.environ.get('ZIM_PREFIX','/ext/zims')
CACHE_DIR = PREFIX + '/youtube/cache'
TARGET_SIZE =10000000000  #10GB
# The rest of the paths are computed and represent the standard layout
# Jupyter sets a working director as part of it's setup. We need it's value
HOME = os.environ['HOME']
WORKING_DIR = PREFIX + '/' + PROJECT_NAME + '/working'
PROJECT_DIR = PREFIX + '/' + PROJECT_NAME + '/tree'
OUTPUT_DIR = PREFIX + '/' + PROJECT_NAME + '/output_tree'
SOURCE_DIR = PREFIX + '/' + PROJECT_NAME + '/zim-src'
NEW_ZIM_DIR = PREFIX + '/' + PROJECT_NAME + '/new-zim'
dir_list = ['output_tree','tree','working/video_json','zim-src','new-zim']
for f in dir_list: 
    if not os.path.isdir(PREFIX + '/' + PROJECT_NAME +'/' + f):
       os.makedirs(PREFIX + '/' + PROJECT_NAME +'/' + f)

# Input the full path of the downloaded ZIM file
zim_path_contents = os.listdir(SOURCE_DIR)
if zim_path_contents:
    ZIM_PATH = SOURCE_DIR + '/' + zim_path_contents[0]
else:
    ZIM_PATH = '%s/%s/zim-src/teded_en_all_2021-01.zim'%(PREFIX,PROJECT_NAME,) 
# abort if the input file cannot be found
if not os.path.exists(ZIM_PATH):
    print('%s path not found. Quitting. . .'%ZIM_PATH)
    exit

# %%
print('This is the PREFIX:%s'%PREFIX)
# Out:
# This is the PREFIX:/home/ghunt/zimtest

# %%
# First we need to get a current copy of the script
dest = PREFIX
# %cp /opt/iiab/iiab-factory/content/kiwix/de-namespace.sh {dest}

# %%
# The following command will zimdump to the "tree" directory
#  Despite the name, removing namespaces seems unnecessary, and more complex
# It will return without doing anything if the "tree' is not empty
progname = HOME + '/zimtest/de-namespace.sh'
# !{progname} {ZIM_PATH} {PROJECT_NAME}

# %% [markdown]
# * The next step is a manual one that you will need to do with your browser. That is: to verify that after the namespace directories were removed, and all of the html links have been adjusted correctly. Point your browser to <hostname>/zimtest/\<PROJECT_NAME\>/tree.
# * If everything is working, it's time to go fetch the information about each video from youtube.

# %%
ydl = youtube_dl.YoutubeDL()

downloaded = 0
skipped = 0
# Create a list of youtube id's
yt_id_list = os.listdir(PROJECT_DIR + '/videos/')
for yt_id in iter(yt_id_list):
    if os.path.exists(CACHE_DIR + '/video_json/' + yt_id + '.json'):
        # skip over items that are already downloadd
        skipped += 1
        continue
    with ydl:
       result = ydl.extract_info(
                'http://www.youtube.com/watch?v=%s'%yt_id,
                download=False # We just want to extract the info
                )
       downloaded += 1

    with open(CACHE_DIR + '/video_json/' + yt_id + '.json','w') as fp:
        fp.write(json.dumps(result))
    #pprint.pprint(result['upload_date'],result['view_count'])
print('%s skipped and %s downloaded'%(skipped,downloaded))
# Out:
# 1811 skipped and 0 downloaded

# %% [markdown]
# #### Playlist Navigation to Videos
# * On the home page there is a drop down selector which lists about 70 cateegories (or playlists).
# * The value from that drop down is used to pick an entry in "-/assets/data.js", which in turn specifies the playlist of yourtube ID"s that are displayed when a selection is made.

# %%
def get_assets_data():
    # the file <root>/assets/data.js holds the category to video mappings
    outstr = '['
    data = {}
    with open(PROJECT_DIR + '/assets/data.js', 'r') as fp:
    #with open(OUTPUT_DIR + '/assets/data.js', 'r') as fp:
        line = fp.readline()
        while True:
            if line.startswith('var') or not line :
                if len(outstr) > 3:
                    # clip off the trailing semicolon
                    outstr = outstr[:-2]
                    try:
                        data[cat] = json.loads(outstr)
                    except Exception:
                        print('Parse error: %s'%outstr[:80])
                        exit
                cat = line[9:-4]
                outstr = '['
                if not line: break
            else:
                outstr += line
            line = fp.readline()
    return data

zim_category_js = get_assets_data()
#print(json.dumps(zim_category_js,indent=2))
def get_zim_data(yt_id):
    rtn_dict = {}
    for cat in  iter(zim_category_js.keys()):
        for video in range(len(zim_category_js[cat])):
            if zim_category_js[cat][video]['id'] == yt_id:
                rtn_dict = zim_category_js[cat][video]
                break
        if len(rtn_dict) > 0: break
    return rtn_dict
ans = get_zim_data('usdJgEwMinM')
#print(json.dumps(ans,indent=2))

# %% [markdown]
# #### The following Cell is subroutines and can be left minimized

# %%
from pprint import pprint
from pymediainfo import MediaInfo

def mediainfo_dict(path):
    try:
        minfo = MediaInfo.parse(path)
    except:
        print('mediainfo_dict. file not found: %s'%path)
        return {}
    return minfo.to_data()

def select_info(path):
    global data
    data = mediainfo_dict(path)
    rtn = {}
    for index in range(len(data['tracks'])):
        track = data['tracks'][index]
        if track['kind_of_stream'] == 'General':
            rtn['file_size'] = track.get('file_size',0)
            rtn['bit_rate'] = track.get('overall_bit_rate',0)
            rtn['time'] = track['other_duration'][0]
        if track['kind_of_stream'] == 'Audio':
            rtn['a_stream'] = track.get('stream_size',0)
            rtn['a_rate'] = track.get('maximum_bit_rate',0)
            rtn['a_channels'] = track.get('channel_s',0)
        if track['kind_of_stream'] == 'Video':
            rtn['v_stream'] = track.get('stream_size',0)
            rtn['v_format'] = track['other_format'][0]
            rtn['v_rate'] = track.get('bit_rate',0)
            rtn['v_frame_rate'] = track.get('frame_rate',0)
            rtn['v_width'] = track.get('width',0)
            rtn['v_height'] = track.get('height',0)
    return rtn

# %%
import sqlite3
class Sqlite():
   def __init__(self, filename):
      self.conn = sqlite3.connect(filename)
      self.conn.row_factory = sqlite3.Row
      self.conn.text_factory = str
      self.c = self.conn.cursor()
    
   def __del__(self):
      self.conn.commit()
      self.c.close()
      del self.conn

def get_video_json(path):
    with open(path,'r') as fp:
        try:
            jsonstr = fp.read()
            #print(path)
            modules = json.loads(jsonstr.strip())
        except Exception as e:
            print(e)
            print(jsonstr[:80])
            return {}
    return modules

def video_size(yt_id):
    return os.path.getsize(PROJECT_DIR + '/-/videos/' + yt_id + '/video.webm')

def make_directory(path):
    if not os.path.exists(path):
        os.makedirs(path)

def download_file(url,todir):
    local_filename = url.split('/')[-1]
    r = requests.get(url)
    f = open(todir + '/' + local_filename, 'wb')
    for chunk in r.iter_content(chunk_size=512 * 1024):
        if chunk:
            f.write(chunk)
    f.close()
    
from datetime import datetime
def age_in_years(upload_date):
    uploaded_dt = datetime.strptime(upload_date,"%Y%m%d")
    now_dt = datetime.now()
    days_delta = now_dt - uploaded_dt
    years = days_delta.days/365 + 1
    return years

# %% [markdown]
# #### Create a sqlite database which collects Data about each Video
# * We've already downloaded the data from YouTube for each Video. So get the items that are interesing to us. Such as size,date uploaded to youtube,view count

# %%
def initialize_db():
    sql = 'CREATE TABLE IF NOT EXISTS video_info ('\
            'yt_id TEXT UNIQUE, zim_size INTEGER, view_count INTEGER, age INTEGER, '\
            'views_per_year INTEGER, upload_date TEXT, duration TEXT, '\
            'height INTEGER, width INTEGER,'\
            'bit_rate TEXT, format TEXT, '\
            'average_rating REAL,slug TEXT,title TEXT)'
    db.c.execute(sql)
    
db = Sqlite(WORKING_DIR + '/zim_video_info.sqlite')
initialize_db()
for yt_id in iter(yt_id_list):
    # some defaults
    age = 0
    views_per_year = 1
    # fetch data from assets/data.js
    zim_data = get_zim_data(yt_id)
    if len(zim_data) == 0: 
        print('get_zim_data returned no data for %s'%yt_id)
    slug = zim_data['slug']
    
    # We already have youtube data for every video, use it 
    data = get_video_json(CACHE_DIR + "/video_json/" + yt_id + '.json')
    if len(data) == 0:
        print('get_video_json returned no data for %s'%yt_id)
    vsize = data.get('filesize',0)
    view_count = data.get('view_count',0)
    upload_date = data.get('upload_date','')
    average_rating = data.get('average_rating',0)
    title = data.get('title','unknown title')
    # calculate the views_per_year since it was uploaded
    if upload_date != '':
        age = round(age_in_years(upload_date))
        views_per_year = int(view_count / age)
        
    # interogate the video itself
    filename = PROJECT_DIR + '/videos/' + yt_id + '/video.webm'
    if os.path.isfile(filename):
        vsize = os.path.getsize(filename)
        #print('vsize:%s'%vsize)
        selected_data = select_info(filename)
        if len(selected_data) == 0:
            duration = "not found"
            bit_rate = "" 
            v_format = ""
        else:
            duration = selected_data['time']
            bit_rate = selected_data['bit_rate']
            v_format = selected_data['v_format']
            v_height = selected_data['v_height']
            v_width = selected_data['v_width']
    
    # colums names: yt_id,zim_size,view_count,views_per_year,upload_date,duration,
    #         bit_rate, format,average_rating,slug
    sql = 'INSERT OR REPLACE INTO video_info VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?)'
    db.c.execute(sql,[yt_id,vsize,view_count,round(age),views_per_year,upload_date, \
                      duration,v_height,v_width,bit_rate,v_format,average_rating,slug,title, ])
db.conn.commit()
print(yt_id,vsize,view_count,views_per_year,upload_date, \
                      duration,bit_rate,v_format,average_rating,slug,round(age))
# Out:
# Expecting value: line 1 column 1 (char 0)
#
# get_video_json returned no data for 9mcuIc5O-DE
# Expecting value: line 1 column 1 (char 0)
#
# get_video_json returned no data for XSb-pIloOFc
# I2apGYUX7Q0 16108773 2871418 287141 20120311 6 min 3 s 354180 VP8 4.7891874 why_can_t_we_see_evidence_of_alien_life 10

# %% [raw]
# sqlite_db = WORKING_DIR + '/zim_video_info.sqlite'
# !sqlite3 {sqlite_db} '.headers on' 'select * from video_info limit 2'

# %% [markdown]
# #### Select the cutoff using view count and total size
# * Order the videos by view count. Then select the sum line in the that has the target sum.

# %%
import pandas as pd
from IPython.display import display 
global tot_sum

def human_readable(num):
    # return 3 significant digits and unit specifier
    num = float(num)
    units = [ '','K','M','G']
    for i in range(4):
        if num<10.0:
            return "%.2f%s"%(num,units[i])
        if num<100.0:
            return "%.1f%s"%(num,units[i])
        if num < 1000.0:
            return "%.0f%s"%(num,units[i])
        num /= 1024.0

sql = 'select slug,zim_size,views_per_year,view_count,duration,upload_date,'\
       'bit_rate from video_info order by views_per_year desc'
tot_sum = 0
db.c.execute(sql)
rows = db.c.fetchall()
row_list = []
boundary_views_per_year = 0
for row in rows:
    tot_sum += row['zim_size']
    row_list.append([row['slug'][:60],human_readable(row['zim_size']),\
                              human_readable(tot_sum),human_readable(row['view_count']),\
                              human_readable(row['views_per_year']),\
                              row['upload_date'],row['duration'],row['bit_rate']])
    if tot_sum > TARGET_SIZE and boundary_views_per_year == 0:
        boundary_views_per_year = row['views_per_year']
sql = 'select slug,zim_size,views_per_year,view_count,duration,upload_date,'\
       'format,width,height,bit_rate from video_info order by views_per_year desc'
db.c.execute(sql)
rows = db.c.fetchall()
print('%60s %6s %6s %6s %6s %8s %8s'%('Name','Size','Sum','Views','Views','Date  ','Duration'))
print('%60s %6s %6s %6s %6s %8s %8s'%('','','','','/ yr','',''))
tot_sum = 0
for row in rows:
    tot_sum += row['zim_size']
    print('%60s %6s %6s %6s %6s %8s %8s'%(row['slug'][:60],human_readable(row['zim_size']),\
                              human_readable(tot_sum),human_readable(row['view_count']),\
                              human_readable(row['views_per_year']),\
                              row['upload_date'],row['duration']))
#df = pd.read_sql(sql,db.conn)
#df = pd.DataFrame(row_list,columns=['Name','Size','Sum','Views','Views','Date','Duration','Bit Rate'])
#display(df)
# Out:
#                                                         Name   Size    Sum  Views  Views   Date   Duration
#                                                                                     / yr
#           can_you_solve_the_prisoner_hat_riddle_alex_gendler  6.65M  6.65M  19.6M  3.27M 20151005 4 min 34 s
#                       how_thor_got_his_hammer_scott_a_mellor  8.02M  14.7M  9.68M  3.23M 20190107 4 min 51 s
#                 which_is_stronger_glue_or_tape_elizabeth_cox  12.6M  27.3M  10.8M  2.71M 20180430 4 min 50 s
#      what_are_those_floaty_things_in_your_eye_michael_mauser  6.76M  34.0M  18.6M  2.66M 20141201 4 min 4 s
#                  is_marijuana_bad_for_your_brain_anees_bahji  12.1M  46.2M  4.89M  2.45M 20191202 6 min 43 s
#                     the_infinite_hotel_paradox_jeff_dekofsky  9.92M  56.1M  19.1M  2.39M 20140116 5 min 59 s
#                 can_you_solve_the_bridge_riddle_alex_gendler  6.09M  62.2M  16.6M  2.38M 20150901 3 min 49 s
#                    a_brie_f_history_of_cheese_paul_kindstedt  7.95M  70.1M  7.05M  2.35M 20181213 5 min 33 s
#  why_don_t_perpetual_motion_machines_ever_work_netta_schramm  16.6M  86.7M  11.0M  2.20M 20170605 5 min 30 s
#          can_you_solve_the_wizard_standoff_riddle_dan_finkel  8.15M  94.9M  8.75M  2.19M 20180522 5 min 25 s
#                          history_s_worst_nun_theresa_a_yugar  13.6M   109M  4.29M  2.14M 20191121 4 min 46 s
#           questions_no_one_knows_the_answers_to_full_version  34.0M   143M  21.4M  2.14M 20120317 12 min 7 s
#     the_tale_of_the_doctor_who_defied_death_iseult_gillespie  9.68M   152M  4.23M  2.11M 20200312 5 min 27 s
#                            the_language_of_lying_noah_zandan  8.93M   161M  14.4M  2.06M 20141103 5 min 41 s
#                       what_makes_muscles_grow_jeffrey_siegel  6.63M   168M  11.9M  1.99M 20151103 4 min 19 s
#             can_you_solve_the_three_gods_riddle_alex_gendler  7.41M   175M  9.52M  1.90M 20170221 4 min 53 s
#          a_day_in_the_life_of_a_roman_soldier_robert_garland  9.16M   184M  7.59M  1.90M 20180329 4 min 59 s
#                          the_surprising_effects_of_pregnancy  19.8M   204M  1.77M  1.77M 20201001 5 min 45 s
#                    can_you_solve_the_virus_riddle_lisa_winer  9.66M   214M  8.58M  1.72M 20170403 5 min 12 s
#            can_you_solve_einsteins_riddle_dan_van_der_vieren  8.86M   223M  10.3M  1.71M 20151130 5 min 12 s
# how_to_practice_effectively_for_just_about_anything_annie_bo  9.17M   232M  8.50M  1.70M 20170227 4 min 49 s
#   why_incompetent_people_think_they_re_amazing_david_dunning  10.9M   243M  6.66M  1.66M 20171109 5 min 7 s
#          can_you_solve_the_prisoner_boxes_riddle_yossi_elran  9.44M   252M  8.26M  1.65M 20161003 4 min 51 s
# can_you_solve_the_famously_difficult_green_eyed_logic_puzzle  8.05M   260M  11.5M  1.64M 20150616 4 min 41 s
#                         the_myth_of_arachne_iseult_gillespie  9.15M   269M  6.46M  1.61M 20180208 4 min 29 s
#                    the_myth_of_pandoras_box_iseult_gillespie  10.9M   280M  4.73M  1.58M 20190115 4 min 9 s
#     what_would_happen_if_you_didnt_drink_water_mia_nacamulli  8.75M   289M  9.38M  1.56M 20160329 4 min 51 s
#         what_would_happen_if_you_didnt_sleep_claudia_aguirre  7.82M   297M  9.24M  1.54M 20151112 4 min 34 s
#                   can_you_solve_the_locker_riddle_lisa_winer  6.77M   304M  9.20M  1.53M 20160328 3 min 49 s
#                            the_myth_of_sisyphus_alex_gendler  9.76M   313M  4.48M  1.49M 20181113 4 min 56 s
#                 can_you_solve_the_pirate_riddle_alex_gendler  9.00M   322M  7.46M  1.49M 20170501 5 min 23 s
#                   how_your_digestive_system_works_emma_bryce  6.85M   329M  5.85M  1.46M 20171214 4 min 56 s
#             how_do_cigarettes_affect_the_body_krishna_sudhir  12.7M   342M  5.85M  1.46M 20180913 5 min 20 s
#                  the_myth_of_cupid_and_psyche_brendan_pelsue  16.4M   358M  7.31M  1.46M 20170803 5 min 32 s
# what_really_happened_during_the_salem_witch_trials_brian_a_p  10.1M   368M  2.92M  1.46M 20200504 5 min 30 s
#                   the_loathsome_lethal_mosquito_rose_eveleth  4.87M   373M  11.6M  1.45M 20131202 2 min 39 s
# which_is_better_soap_or_hand_sanitizer_alex_rosenthal_and_pa  14.0M   387M  2.90M  1.45M 20200505 6 min 14 s
#                       does_time_exist_andrew_zimmerman_jones  15.1M   402M  4.33M  1.44M 20181023 5 min 15 s
#        how_the_food_you_eat_affects_your_brain_mia_nacamulli  14.6M   417M  8.64M  1.44M 20160621 4 min 52 s
#         can_you_solve_the_unstoppable_blob_riddle_dan_finkel  5.70M   423M  4.28M  1.43M 20190318 3 min 42 s
# the_myth_of_thor_s_journey_to_the_land_of_giants_scott_a_mel  7.63M   430M  5.69M  1.42M 20180222 5 min 17 s
#                        a_brief_history_of_chess_alex_gendler  9.53M   440M  4.26M  1.42M 20190912 5 min 39 s
#                     why_do_cats_act_so_weird_tony_buffington  11.9M   452M  8.42M  1.40M 20160426 4 min 57 s
#                                      when_is_a_pandemic_over  15.3M   467M  2.80M  1.40M 20200601 5 min 52 s
#                      the_myth_of_prometheus_iseult_gillespie  8.23M   475M  5.57M  1.39M 20171114 4 min 46 s
#                          why_can_t_you_divide_by_zero_ted_ed  7.70M   483M  5.56M  1.39M 20180423 4 min 50 s
#                      a_brief_history_of_alcohol_rod_phillips  8.92M   492M  2.76M  1.38M 20200102 5 min 20 s
# who_were_the_vestal_virgins_and_what_was_their_job_peta_gree  12.8M   505M  6.85M  1.37M 20170530 4 min 32 s
#       the_tragic_myth_of_orpheus_and_eurydice_brendan_pelsue  7.92M   513M  5.43M  1.36M 20180111 4 min 41 s
#              can_you_solve_the_temple_riddle_dennis_e_shasha  6.70M   519M  8.12M  1.35M 20160201 4 min 12 s
#                can_you_solve_the_egg_drop_riddle_yossi_elran  8.41M   528M  5.38M  1.34M 20171107 4 min 46 s
#   the_tale_of_the_boy_who_tricked_the_devil_iseult_gillespie  17.9M   546M  2.69M  1.34M 20200707 5 min 25 s
# what_happens_to_our_bodies_after_we_die_farnaz_khatibi_jafar  8.41M   554M  6.66M  1.33M 20161013 4 min 40 s
#        can_you_solve_the_counterfeit_coin_riddle_jennifer_lu  9.45M   564M  6.66M  1.33M 20170103 4 min 34 s
#     the_chinese_myth_of_the_immortal_white_snake_shunan_teng  7.80M   571M  3.96M  1.32M 20190507 4 min 0 s
#                  how_does_alcohol_make_you_drunk_judy_grisel  8.19M   580M  2.62M  1.31M 20200409 5 min 25 s
#                        how_does_anesthesia_work_steven_zheng  8.05M   588M  7.82M  1.30M 20151207 4 min 55 s
#              the_benefits_of_a_bilingual_brain_mia_nacamulli  11.5M   599M  9.09M  1.30M 20150623 5 min 3 s
# which_type_of_milk_is_best_for_you_jonathan_j_osullivan_grac  19.1M   618M  1.28M  1.28M 20201020 5 min 25 s
# the_myth_of_king_midas_and_his_golden_touch_iseult_gillespie  16.3M   634M  5.03M  1.26M 20180305 5 min 4 s
#                 can_you_solve_the_passcode_riddle_ganesh_pai  7.16M   642M  7.48M  1.25M 20160707 4 min 7 s
#       how_does_the_rorschach_inkblot_test_work_damion_searls  12.9M   655M  3.71M  1.24M 20190305 4 min 57 s
#                     how_sugar_affects_the_brain_nicole_avena  16.5M   671M  9.83M  1.23M 20140107 5 min 2 s
#  why_doesnt_the_leaning_tower_of_pisa_fall_over_alex_gendler  9.48M   681M  2.45M  1.22M 20191203 5 min 5 s
#   the_history_of_the_world_according_to_cats_eva_maria_geigl  11.9M   693M  3.67M  1.22M 20190103 4 min 34 s
#                cannibalism_in_the_animal_kingdom_bill_schutt  9.64M   702M  4.89M  1.22M 20180319 4 min 57 s
#                the_psychology_of_narcissism_w_keith_campbell  8.95M   711M  7.33M  1.22M 20160223 5 min 9 s
# mating_frenzies_sperm_hoards_and_brood_raids_the_life_of_a_f  12.0M   723M  2.35M  1.17M 20200116 5 min 18 s
#  how_playing_an_instrument_benefits_your_brain_anita_collins  8.59M   732M  9.14M  1.14M 20140722 4 min 44 s
#       the_rise_and_fall_of_the_berlin_wall_konrad_h_jarausch  9.52M   741M  5.70M  1.14M 20170816 6 min 25 s
#                   how_does_a_jellyfish_sting_neosha_s_kashef  7.51M   749M  7.97M  1.14M 20150810 4 min 16 s
# what_if_there_were_1_trillion_more_trees_jean_francois_basti  24.6M   773M  1.14M  1.14M 20201027 5 min 43 s
#              how_does_the_stock_market_work_oliver_elfenbaum  9.18M   782M  3.41M  1.14M 20190429 4 min 29 s
#      5_tips_to_improve_your_critical_thinking_samantha_agoos  6.79M   789M  6.82M  1.14M 20160315 4 min 29 s
# from_slave_to_rebel_gladiator_the_life_of_spartacus_fiona_ra  19.2M   808M  3.40M  1.13M 20181217 5 min 15 s
#                 the_benefits_of_good_posture_murat_dalkilinc  5.78M   814M  7.89M  1.13M 20150730 4 min 26 s
#                           what_is_depression_helen_m_farrell  7.12M   821M  6.74M  1.12M 20151215 4 min 28 s
# how_did_hitler_rise_to_power_alex_gendler_and_anthony_hazard  11.7M   833M  6.73M  1.12M 20160718 5 min 36 s
#       a_glimpse_of_teenage_life_in_ancient_rome_ray_laurence  15.9M   849M  10.1M  1.12M 20121029 6 min 34 s
#                  the_worlds_most_mysterious_book_stephen_bax  9.37M   858M  5.58M  1.12M 20170525 4 min 42 s
#                       3_tips_to_boost_your_confidence_ted_ed  9.28M   868M  6.66M  1.11M 20151006 4 min 16 s
#                   can_you_solve_the_frog_riddle_derek_abbott  6.91M   875M  6.61M  1.10M 20160229 4 min 30 s
# the_unexpected_math_behind_van_gogh_s_starry_night_natalya_s  14.7M   889M  7.69M  1.10M 20141030 4 min 38 s
#                   the_myth_of_icarus_and_daedalus_amy_adkins  15.2M   904M  5.47M  1.09M 20170313 5 min 8 s
# a_day_in_the_life_of_an_ancient_egyptian_doctor_elizabeth_co  7.03M   911M  4.35M  1.09M 20180719 4 min 33 s
# the_myth_behind_the_chinese_zodiac_megan_campisi_and_pen_pen  6.53M   918M  5.42M  1.08M 20170126 4 min 22 s
# the_atlantic_slave_trade_what_too_few_textbooks_told_you_ant  10.8M   929M  7.55M  1.08M 20141222 5 min 38 s
#                 the_philosophy_of_stoicism_massimo_pigliucci  10.3M   939M  5.38M  1.08M 20170619 5 min 29 s
#        the_myth_of_hercules_12_labors_in_8_bits_alex_gendler  23.8M   963M  4.30M  1.07M 20180925 7 min 50 s
#                        historys_deadliest_colors_j_v_maranto  14.5M   977M  5.36M  1.07M 20170522 5 min 13 s
#                   how_to_spot_a_pyramid_scheme_stacie_bosley  7.23M   985M  3.20M  1.07M 20190402 5 min 1 s
#                          are_the_illuminati_real_chip_berlet  7.43M   992M  2.11M  1.05M 20191031 4 min 57 s
#           can_you_solve_the_river_crossing_riddle_lisa_winer  8.29M  0.98G  5.16M  1.03M 20161101 4 min 18 s
#                            what_is_schizophrenia_anees_bahji  10.5M  0.99G  2.06M  1.03M 20200326 5 min 32 s
#              can_you_solve_the_airplane_riddle_judd_a_schorr  9.30M  1.00G  5.09M  1.02M 20161201 4 min 37 s
#                  the_history_of_chocolate_deanna_pucciarelli  8.67M  1.00G  5.07M  1.01M 20170316 4 min 40 s
#         hawking_s_black_hole_paradox_explained_fabio_pacucci  11.2M  1.02G  2.00M  1.00M 20191022 5 min 37 s
#                 can_you_solve_the_ragnarok_riddle_dan_finkel  22.4M  1.04G  1.99M  0.99M 20200630 5 min 14 s
# the_legend_of_annapurna_hindu_goddess_of_nourishment_antara_  8.40M  1.05G  1.97M  0.98M 20200213 5 min 8 s
#                       the_bug_that_poops_candy_george_zaidan  14.1M  1.06G  1.95M   999K 20200414 4 min 46 s
#                                    why_do_women_have_periods  7.05M  1.07G  5.86M   999K 20151019 4 min 45 s
#              why_are_some_people_left_handed_daniel_m_abrams  8.22M  1.07G  6.77M   990K 20150203 5 min 6 s
#                                    why_do_we_itch_emma_bryce  13.6M  1.09G  4.83M   988K 20170411 4 min 43 s
#     can_you_solve_the_penniless_pilgrim_riddle_daniel_finkel  6.60M  1.09G  3.84M   983K 20180604 4 min 44 s
#    the_three_different_ways_mammals_give_birth_kate_slabosky  8.55M  1.10G  4.77M   977K 20170417 4 min 49 s
#   the_surprising_reason_our_muscles_get_tired_christian_moro  10.6M  1.11G  2.84M   971K 20190418 4 min 24 s
#                  what_makes_something_kafkaesque_noah_tavlin  19.7M  1.13G  5.68M   970K 20160620 5 min 3 s
#                 can_you_solve_the_fish_riddle_steve_wyborney  8.49M  1.14G  4.71M   964K 20170626 4 min 49 s
#                how_does_laser_eye_surgery_work_dan_reinstein  12.1M  1.15G  1.87M   960K 20191119 5 min 36 s
# the_egyptian_book_of_the_dead_a_guidebook_for_the_underworld  7.39M  1.16G  4.62M   945K 20161031 4 min 31 s
#                            history_vs_cleopatra_alex_gendler  7.53M  1.17G  4.61M   943K 20170202 4 min 27 s
#                the_five_major_world_religions_john_bellaimey  36.6M  1.20G  7.32M   937K 20131114 11 min 9 s
#                            how_do_tornadoes_form_james_spann  8.52M  1.21G  7.31M   936K 20140819 4 min 11 s
#        history_through_the_eyes_of_a_chicken_chris_a_kniesly  14.1M  1.22G  2.73M   932K 20181011 5 min 11 s
#               einstein_s_twin_paradox_explained_amber_stuver  11.7M  1.24G  2.71M   926K 20190926 6 min 15 s
#                      the_dark_history_of_bananas_john_soluri  17.6M  1.25G   925K   925K 20201102 6 min 2 s
#                    four_sisters_in_ancient_rome_ray_laurence  17.2M  1.27G  8.04M   915K 20130514 8 min 38 s
#       the_greek_myth_of_talos_the_first_robot_adrienne_mayor  8.36M  1.28G  1.79M   914K 20191024 4 min 6 s
# how_to_manage_your_time_more_effectively_according_to_machin  7.65M  1.29G  3.54M   906K 20180102 5 min 9 s
#                       where_does_gold_come_from_david_lunney  9.66M  1.29G  5.23M   892K 20151008 4 min 34 s
#                   a_brief_history_of_cannibalism_bill_schutt  8.18M  1.30G  2.60M   889K 20190725 4 min 49 s
#    the_rise_and_fall_of_the_byzantine_empire_leonora_neville  8.15M  1.31G  3.47M   888K 20180409 5 min 20 s
#                                   why_do_we_dream_amy_adkins  13.5M  1.32G  5.13M   876K 20151210 5 min 37 s
#          the_fascinating_history_of_cemeteries_keith_eggener  9.83M  1.33G  2.57M   876K 20181030 5 min 18 s
#            what_happens_during_a_heart_attack_krishna_sudhir  8.09M  1.34G  4.26M   873K 20170214 4 min 53 s
#                   why_sitting_is_bad_for_you_murat_dalkilinc  8.20M  1.35G  5.86M   858K 20150305 5 min 4 s
#                          history_vs_che_guevara_alex_gendler  11.8M  1.36G  3.35M   856K 20171127 6 min 7 s
#       why_should_you_read_dune_by_frank_herbert_dan_kwartler  12.1M  1.37G  1.67M   856K 20191217 5 min 5 s
# how_to_stay_calm_under_pressure_noa_kageyama_and_pen_pen_che  8.06M  1.38G  3.33M   851K 20180521 4 min 28 s
#                how_does_money_laundering_work_delena_d_spann  11.9M  1.39G  4.10M   839K 20170523 4 min 46 s
#   the_great_conspiracy_against_julius_caesar_kathryn_tempest  10.4M  1.40G  5.72M   837K 20141218 5 min 57 s
# mansa_musa_one_of_the_wealthiest_people_who_ever_lived_jessi  12.4M  1.41G  5.72M   837K 20150518 3 min 54 s
# why_do_animals_have_such_different_lifespans_joao_pedro_de_m  7.36M  1.42G  4.02M   823K 20170404 4 min 56 s
#                               how_tsunamis_work_alex_gendler  8.95M  1.43G  6.41M   820K 20140424 3 min 36 s
#    the_rise_and_fall_of_the_mongol_empire_anne_f_broadbridge  12.1M  1.44G  2.39M   817K 20190829 5 min 0 s
#                               the_history_of_tea_shunan_teng  7.57M  1.45G  3.98M   815K 20170516 4 min 57 s
#         the_mysterious_life_and_death_of_rasputin_eden_girma  8.68M  1.46G  1.58M   810K 20200107 5 min 13 s
# licking_bees_and_pulping_trees_the_reign_of_a_wasp_queen_ken  10.9M  1.47G  1.58M   809K 20200128 5 min 22 s
#                          why_are_sloths_so_slow_kenny_coogan  7.71M  1.48G  3.95M   809K 20170425 5 min 14 s
#         can_you_solve_the_stolen_rubies_riddle_dennis_shasha  10.1M  1.49G  2.36M   805K 20181025 4 min 50 s
# why_isn_t_the_world_covered_in_poop_eleanor_slade_and_paul_m  7.34M  1.49G  3.10M   793K 20180326 4 min 57 s
#                            what_makes_a_hero_matthew_winkler  11.4M  1.50G  6.93M   789K 20121204 4 min 33 s
# the_cambodian_myth_of_lightning_thunder_and_rain_prumsodun_o  11.6M  1.52G  3.07M   785K 20180410 4 min 37 s
#                       how_does_asthma_work_christopher_e_gaw  8.91M  1.52G  3.83M   785K 20170511 5 min 9 s
# meet_the_tardigrade_the_toughest_animal_on_earth_thomas_boot  7.11M  1.53G  3.82M   783K 20170321 4 min 9 s
#          can_you_solve_the_control_room_riddle_dennis_shasha  6.73M  1.54G  4.58M   781K 20160531 4 min 0 s
#        can_you_solve_the_dragon_jousting_riddle_alex_gendler  9.13M  1.55G  1.51M   771K 20200109 5 min 3 s
#                whats_that_ringing_in_your_ears_marc_fagelson  22.4M  1.57G  1.50M   770K 20200817 5 min 38 s
#                  why_the_metric_system_matters_matt_anticole  7.17M  1.58G  4.51M   770K 20160721 5 min 7 s
# schrodinger_s_cat_a_thought_experiment_in_quantum_mechanics_  6.93M  1.58G  5.25M   768K 20141014 4 min 37 s
#                can_you_solve_the_dark_coin_riddle_lisa_winer  9.85M  1.59G  3.00M   768K 20180122 5 min 25 s
#         can_you_solve_the_seven_planets_riddle_edwin_f_meyer  9.29M  1.60G  2.98M   762K 20180226 6 min 0 s
#   the_myth_of_loki_and_the_deadly_mistletoe_iseult_gillespie  22.2M  1.62G   756K   756K 20201201 5 min 28 s
#                           what_causes_headaches_dan_kwartler  9.18M  1.63G  2.94M   754K 20180412 5 min 31 s
#    can_you_solve_the_multiplying_rabbits_riddle_alex_gendler  7.66M  1.64G  2.20M   752K 20190110 4 min 38 s
#                  why_is_it_so_hard_to_cure_cancer_kyuson_yun  14.5M  1.65G  2.91M   746K 20171010 5 min 22 s
#                        why_do_people_join_cults_janja_lalich  12.4M  1.67G  3.63M   744K 20170612 6 min 26 s
#          can_you_solve_the_secret_werewolf_riddle_dan_finkel  7.43M  1.67G  2.18M   744K 20181108 4 min 28 s
#          the_wars_that_inspired_game_of_thrones_alex_gendler  11.0M  1.68G  5.07M   741K 20150511 6 min 0 s
#   can_you_solve_the_leonardo_da_vinci_riddle_tanya_khovanova  7.97M  1.69G  2.89M   741K 20180823 5 min 7 s
#          why_do_we_cry_the_three_types_of_tears_alex_gendler  7.77M  1.70G  5.74M   734K 20140226 3 min 58 s
# does_your_vote_count_the_electoral_college_explained_christi  11.1M  1.71G  6.44M   732K 20121101 5 min 21 s
#               can_you_solve_the_jail_break_riddle_dan_finkel  7.25M  1.72G  2.14M   732K 20190226 3 min 24 s
#      how_we_conquered_the_deadly_smallpox_virus_simona_zompi  9.12M  1.73G  5.66M   725K 20131028 4 min 33 s
#   would_you_sacrifice_one_person_to_save_five_eleanor_nelsen  7.06M  1.73G  3.52M   721K 20170112 4 min 55 s
#                      what_causes_kidney_stones_arash_shadman  6.68M  1.74G  3.51M   719K 20170703 5 min 14 s
# how_the_world_s_longest_underwater_tunnel_was_built_alex_gen  9.61M  1.75G  1.40M   717K 20200330 5 min 37 s
# why_is_vermeer_s_girl_with_the_pearl_earring_considered_a_ma  8.37M  1.76G  3.50M   716K 20161018 4 min 33 s
#                        how_do_solar_panels_work_richard_komp  7.14M  1.76G  4.17M   712K 20160105 4 min 58 s
#   why_the_octopus_brain_is_so_extraordinary_claudio_l_guerra  7.17M  1.77G  4.17M   711K 20151203 4 min 16 s
# what_would_happen_if_every_human_suddenly_disappeared_dan_kw  9.30M  1.78G  2.77M   710K 20180917 5 min 21 s
#                           what_causes_cavities_mel_rosenberg  9.96M  1.79G  3.46M   708K 20161017 5 min 0 s
#     the_greatest_mathematician_that_never_lived_pratik_aghor  16.1M  1.81G  1.38M   707K 20200706 5 min 12 s
#                     what_is_bipolar_disorder_helen_m_farrell  8.08M  1.81G  3.44M   704K 20170209 5 min 57 s
#         can_you_solve_the_riddle_and_escape_hades_dan_finkel  15.3M  1.83G   702K   702K 20201013 4 min 59 s
#              can_you_solve_the_sea_monster_riddle_dan_finkel  12.4M  1.84G  1.37M   701K 20200402 5 min 27 s
#         can_you_solve_the_false_positive_riddle_alex_gendler  10.4M  1.85G  2.73M   699K 20180508 5 min 19 s
#                         history_vs_genghis_khan_alex_gendler  10.4M  1.86G  4.77M   698K 20150702 6 min 6 s
#             can_you_solve_the_cheating_royal_riddle_dan_katz  19.3M  1.88G  1.36M   695K 20200811 5 min 48 s
# the_dark_ages_how_dark_were_they_really_crash_course_world_h  29.8M  1.91G  6.78M   695K 20120426 12 min 7 s
#                      where_did_russia_come_from_alex_gendler  13.9M  1.92G  4.06M   693K 20151013 5 min 19 s
# mary_s_room_a_philosophical_thought_experiment_eleanor_nelse  6.90M  1.93G  3.38M   692K 20170124 4 min 51 s
#             ancient_romes_most_notorious_doctor_ramon_glazov  8.17M  1.94G  2.02M   689K 20190718 5 min 10 s
#           no_one_can_figure_out_how_eels_have_sex_lucy_cooke  22.0M  1.96G  1.34M   684K 20200727 6 min 1 s
#                  how_to_build_a_fictional_world_kate_messner  10.1M  1.97G  5.33M   682K 20140109 5 min 24 s
#               how_stress_affects_your_brain_madhumita_murgia  7.50M  1.98G  4.00M   682K 20151109 4 min 15 s
#              can_you_solve_the_time_travel_riddle_dan_finkel  8.14M  1.98G  1.97M   674K 20181204 4 min 31 s
#                 can_you_solve_the_rogue_ai_riddle_dan_finkel  9.02M  1.99G  2.62M   671K 20180807 5 min 12 s
#           can_you_outsmart_this_logical_fallacy_alex_gendler  6.02M  2.00G  1.31M   670K 20191125 3 min 44 s
# the_egyptian_myth_of_isis_and_the_seven_scorpions_alex_gendl  8.66M  2.01G  1.31M   669K 20200302 3 min 34 s
#   why_should_you_read_tolstoy_s_war_and_peace_brendan_pelsue  10.4M  2.02G  3.26M   668K 20170427 5 min 9 s
#                 the_philosophy_of_cynicism_william_d_desmond  10.2M  2.03G  1.30M   666K 20191219 5 min 25 s
#             cell_vs_virus_a_battle_for_health_shannon_stiles  10.1M  2.04G  5.19M   665K 20140417 3 min 58 s
# what_causes_panic_attacks_and_how_can_you_prevent_them_cindy  17.4M  2.05G   662K   662K 20201008 5 min 22 s
#                why_isnt_the_netherlands_underwater_stefan_al  10.3M  2.06G  1.29M   662K 20200324 5 min 23 s
#                      how_do_pregnancy_tests_work_tien_nguyen  8.90M  2.07G  4.51M   660K 20150707 4 min 33 s
#         how_stress_affects_your_body_sharon_horesh_bergquist  8.32M  2.08G  3.85M   658K 20151022 4 min 42 s
#        the_egyptian_myth_of_the_death_of_osiris_alex_gendler  20.5M  2.10G  1.28M   656K 20200716 4 min 14 s
# what_is_imposter_syndrome_and_how_can_you_combat_it_elizabet  6.54M  2.11G  2.56M   655K 20180828 4 min 18 s
#    can_you_solve_the_alice_in_wonderland_riddle_alex_gendler  16.9M  2.12G   652K   652K 20201117 5 min 4 s
#      a_day_in_the_life_of_an_ancient_athenian_robert_garland  10.1M  2.13G  2.55M   652K 20180315 5 min 1 s
# what_makes_the_great_wall_of_china_so_extraordinary_megan_ca  6.95M  2.14G  4.45M   650K 20150917 4 min 29 s
#         the_myth_of_loki_and_the_master_builder_alex_gendler  7.81M  2.15G  1.26M   647K 20191114 4 min 37 s
#                     platos_allegory_of_the_cave_alex_gendler  13.0M  2.16G  4.41M   645K 20150317 4 min 32 s
#                        platos_best_and_worst_ideas_wisecrack  9.76M  2.17G  3.14M   644K 20161025 4 min 48 s
#                      is_it_bad_to_hold_your_pee_heba_shaheed  6.40M  2.18G  3.13M   641K 20161010 3 min 58 s
# why_should_you_read_lord_of_the_flies_by_william_golding_jil  12.0M  2.19G  1.25M   641K 20191212 4 min 47 s
#           can_you_solve_the_trolls_paradox_riddle_dan_finkel  10.2M  2.20G  1.87M   638K 20181220 3 min 44 s
#         why_do_we_love_a_philosophical_inquiry_skye_c_cleary  9.31M  2.21G  3.74M   637K 20160211 5 min 44 s
#           can_you_solve_the_vampire_hunter_riddle_dan_finkel  5.88M  2.21G  1.86M   636K 20190128 3 min 51 s
#                       a_brief_history_of_dogs_david_ian_howe  9.68M  2.22G  1.86M   634K 20190326 4 min 58 s
# why_should_you_listen_to_vivaldi_s_four_seasons_betsy_schwar  8.74M  2.23G  3.08M   631K 20161024 4 min 19 s
#          why_should_you_read_fahrenheit_451_iseult_gillespie  9.36M  2.24G  1.83M   626K 20190122 4 min 35 s
#                        the_science_of_attraction_dawn_maslar  6.78M  2.25G  4.88M   624K 20140508 4 min 33 s
#                8_traits_of_successful_people_richard_st_john  19.1M  2.27G  5.49M   624K 20130405 7 min 17 s
#                   history_vs_napoleon_bonaparte_alex_gendler  8.85M  2.27G  3.64M   621K 20160204 5 min 21 s
# can_you_solve_the_cuddly_duddly_fuddly_wuddly_riddle_dan_fin  6.06M  2.28G  1.82M   621K 20190425 3 min 34 s
# what_s_the_difference_between_accuracy_and_precision_matt_an  7.40M  2.29G  4.23M   619K 20150414 4 min 52 s
#                 where_do_superstitions_come_from_stuart_vyse  8.38M  2.30G  3.00M   614K 20170309 5 min 10 s
#                       how_a_wound_heals_itself_sarthak_sinha  7.79M  2.30G  4.18M   611K 20141110 4 min 0 s
#                                    just_how_small_is_an_atom  14.7M  2.32G  5.96M   610K 20120416 5 min 27 s
#                      why_elephants_never_forget_alex_gendler  8.72M  2.33G  4.16M   608K 20141113 5 min 22 s
#                  how_does_your_immune_system_work_emma_bryce  9.65M  2.33G  2.37M   606K 20180108 5 min 22 s
#             can_you_solve_the_giant_iron_riddle_alex_gendler  5.39M  2.34G  1.77M   605K 20181127 3 min 37 s
#              the_greatest_ted_talk_ever_sold_morgan_spurlock  38.9M  2.38G  5.31M   605K 20130315 19 min 28 s
#       how_do_carbohydrates_impact_your_health_richard_j_wood  8.69M  2.39G  3.54M   605K 20160111 5 min 10 s
#                 how_does_chemotherapy_work_hyunsoo_joshua_no  12.9M  2.40G  1.17M   601K 20191205 5 min 25 s
#                   can_we_create_the_perfect_farm_brent_loken  31.1M  2.43G   594K   594K 20201012 7 min 9 s
#                     how_to_recognize_a_dystopia_alex_gendler  20.0M  2.45G  2.90M   594K 20161115 5 min 55 s
#         how_the_food_you_eat_affects_your_gut_shilpa_ravella  12.3M  2.46G  2.90M   594K 20170323 5 min 9 s
# zen_koans_unsolvable_enigmas_designed_to_break_your_brain_pu  14.2M  2.48G  2.32M   593K 20180816 4 min 57 s
#                  why_is_cotton_in_everything_michael_r_stiff  10.4M  2.49G  1.15M   591K 20200123 4 min 53 s
#                 the_life_cycle_of_a_cup_of_coffee_a_j_jacobs  20.9M  2.51G   591K   591K 20210104 5 min 4 s
#                 what_makes_tattoos_permanent_claudia_aguirre  8.82M  2.51G  4.61M   590K 20140710 4 min 25 s
#    how_much_of_what_you_see_is_a_hallucination_elizabeth_cox  12.7M  2.53G  2.30M   589K 20180626 5 min 49 s
# what_s_the_fastest_way_to_alphabetize_your_bookshelf_chand_j  6.22M  2.53G  2.87M   589K 20161128 4 min 38 s
#                    the_dangers_of_mixing_drugs_celine_valery  14.3M  2.55G  1.15M   587K 20191112 5 min 3 s
#                  how_does_caffeine_keep_us_awake_hanan_qasim  8.05M  2.55G  2.86M   586K 20170717 5 min 14 s
#           can_you_solve_the_monster_duel_riddle_alex_gendler  16.3M  2.57G   585K   585K 20201208 5 min 35 s
#  can_you_solve_the_worlds_most_evil_wizard_riddle_dan_finkel  8.54M  2.58G  1.14M   584K 20200519 5 min 16 s
#                  how_do_fish_make_electricity_eleanor_nelsen  10.4M  2.59G  2.28M   584K 20171130 5 min 14 s
#          will_there_ever_be_a_mile_high_skyscraper_stefan_al  9.17M  2.60G  1.71M   584K 20190207 5 min 4 s
# everything_changed_when_the_fire_crystal_got_stolen_alex_gen  9.03M  2.61G  1.14M   582K 20200206 4 min 21 s
#                 debunking_the_myths_of_ocd_natascha_m_santos  9.04M  2.62G  3.97M   581K 20150519 4 min 50 s
#           the_rise_and_fall_of_the_inca_empire_gordon_mcewan  14.5M  2.63G  2.27M   580K 20180212 5 min 45 s
# how_do_steroids_affect_your_muscles_and_the_rest_of_your_bod  18.1M  2.65G   580K   580K 20201109 5 min 48 s
#           can_you_solve_the_giant_cat_army_riddle_dan_finkel  9.01M  2.66G  2.26M   578K 20180611 5 min 19 s
#         what_yoga_does_to_your_body_and_brain_krishna_sudhir  19.4M  2.68G  1.13M   577K 20200618 6 min 1 s
#         can_you_solve_the_killer_robo_ants_riddle_dan_finkel  9.24M  2.68G  1.69M   576K 20181009 4 min 51 s
#                 how_do_animals_experience_pain_robyn_j_crook  7.80M  2.69G  2.81M   576K 20170117 5 min 6 s
#                          what_is_a_coronavirus_elizabeth_cox  8.85M  2.70G  1.13M   576K 20200514 5 min 15 s
#            should_you_trust_unanimous_decisions_derek_abbott  6.56M  2.71G  3.37M   575K 20160418 4 min 2 s
#                 why_do_humans_have_a_third_eyelid_dorsa_amir  8.01M  2.71G  1.12M   573K 20191111 4 min 35 s
# why_should_you_read_one_hundred_years_of_solitude_francisco_  14.1M  2.73G  2.23M   571K 20180830 5 min 30 s
#             the_dark_history_of_iq_tests_stefan_c_dombrowski  12.8M  2.74G  1.12M   571K 20200427 6 min 9 s
#                     why_are_there_so_many_insects_murry_gans  7.45M  2.75G  3.34M   571K 20160301 4 min 43 s
#          the_immortal_cells_of_henrietta_lacks_robin_bulleri  9.48M  2.76G  3.34M   570K 20160208 4 min 26 s
#                                what_is_entropy_jeff_phillips  7.75M  2.77G  2.77M   568K 20170509 5 min 19 s
#           can_you_solve_the_secret_sauce_riddle_alex_gendler  7.29M  2.77G  1.65M   565K 20190916 4 min 42 s
#     the_history_of_the_cuban_missile_crisis_matthew_a_jordan  9.69M  2.78G  3.29M   561K 20160926 4 min 51 s
#      can_you_solve_the_buried_treasure_riddle_daniel_griller  9.47M  2.79G  2.19M   561K 20180322 5 min 2 s
#            the_chinese_myth_of_the_meddling_monk_shunan_teng  8.00M  2.80G  1.63M   556K 20190523 4 min 3 s
#                            what_causes_insomnia_dan_kwartler  7.39M  2.81G  2.17M   555K 20180614 5 min 11 s
#   the_history_of_the_world_according_to_corn_chris_a_kniesly  14.0M  2.82G  1.08M   551K 20191126 5 min 22 s
#                   why_should_you_read_macbeth_brendan_pelsue  10.5M  2.83G  2.13M   544K 20171102 6 min 8 s
#                      why_do_your_knuckles_pop_eleanor_nelsen  12.1M  2.84G  3.68M   539K 20150505 4 min 21 s
# how_high_can_you_count_on_your_fingers_spoiler_much_higher_t  9.61M  2.85G  2.63M   538K 20161215 4 min 29 s
#        why_should_you_read_crime_and_punishment_alex_gendler  8.22M  2.86G  1.57M   536K 20190514 4 min 45 s
# how_did_dracula_become_the_world_s_most_famous_vampire_stanl  10.5M  2.87G  2.61M   535K 20170420 5 min 5 s
#           the_most_successful_pirate_of_all_time_dian_murray  8.43M  2.88G  2.08M   531K 20180402 5 min 16 s
# the_journey_to_pluto_the_farthest_world_ever_explored_alan_s  8.63M  2.89G  2.07M   530K 20180517 6 min 9 s
#                    at_what_moment_are_you_dead_randall_hayes  9.25M  2.89G  3.61M   528K 20141211 5 min 33 s
#                     how_blood_pressure_works_wilfred_manzano  8.16M  2.90G  3.59M   525K 20150723 4 min 31 s
#                    where_did_english_come_from_claire_bowern  9.49M  2.91G  3.58M   523K 20150716 4 min 53 s
#              the_benefits_of_a_good_night_s_sleep_shai_marcu  11.3M  2.92G  3.58M   523K 20150105 5 min 44 s
# is_life_meaningless_and_other_absurd_questions_nina_medvinsk  18.8M  2.94G  1.02M   522K 20200921 6 min 12 s
#                     how_do_vitamins_work_ginnie_trinh_nguyen  9.07M  2.95G  3.55M   520K 20141006 4 min 43 s
#                  did_the_amazons_really_exist_adrienne_mayor  14.0M  2.96G  2.01M   516K 20180618 5 min 5 s
#        the_treadmill_s_dark_and_twisted_past_conor_heffernan  14.6M  2.98G  3.52M   514K 20150922 4 min 9 s
#              is_fire_a_solid_a_liquid_or_a_gas_elizabeth_cox  9.93M  2.99G  1.50M   512K 20181105 4 min 34 s
#          how_squids_outsmart_their_predators_carly_anne_york  9.54M  3.00G  2.00M   511K 20180514 5 min 12 s
#                          what_causes_body_odor_mel_rosenberg  6.32M  3.00G  1.99M   510K 20180405 4 min 28 s
#                       the_sonic_boom_problem_katerina_kaouri  11.3M  3.01G  3.48M   509K 20150210 5 min 43 s
#                           a_brief_history_of_goths_dan_adams  11.8M  3.03G  2.48M   509K 20170518 5 min 30 s
#    the_rise_and_fall_of_the_assyrian_empire_marian_h_feldman  12.1M  3.04G  1.98M   508K 20180424 5 min 15 s
#           how_to_outsmart_the_prisoners_dilemma_lucas_husted  22.9M  3.06G  0.99M   507K 20200827 5 min 44 s
#                    how_to_write_descriptively_nalo_hopkinson  12.1M  3.07G  2.96M   505K 20151116 4 min 41 s
#                                how_to_make_a_mummy_len_bloch  7.41M  3.08G  3.43M   501K 20150618 4 min 45 s
#  the_amazing_ways_plants_defend_themselves_valentin_hammoudi  11.5M  3.09G  2.45M   501K 20170828 6 min 11 s
#            how_rollercoasters_affect_your_body_brian_d_avery  9.21M  3.10G  1.47M   500K 20181029 5 min 1 s
#                 if_superpowers_were_real_immortality_joy_lin  14.3M  3.11G  4.40M   500K 20130627 4 min 29 s
#     how_parasites_change_their_host_s_behavior_jaap_de_roode  10.1M  3.12G  3.42M   500K 20150309 5 min 13 s
#            the_pharaoh_that_wouldn_t_be_forgotten_kate_green  9.09M  3.13G  3.41M   499K 20141215 4 min 33 s
# the_myth_of_oisin_and_the_land_of_eternal_youth_iseult_gille  8.19M  3.14G  1.94M   496K 20180118 3 min 49 s
# is_human_evolution_speeding_up_or_slowing_down_laurence_hurs  21.1M  3.16G   985K   492K 20200922 5 min 47 s
#               what_caused_the_french_revolution_tom_mullaney  13.9M  3.17G  2.40M   491K 20161027 5 min 38 s
#            the_myth_of_the_stolen_eyeballs_nathan_d_horowitz  23.6M  3.20G   490K   490K 20201005 5 min 29 s
#       what_is_the_tragedy_of_the_commons_nicholas_amendolare  12.4M  3.21G  1.91M   490K 20171121 4 min 57 s
#                          how_to_unboil_an_egg_eleanor_nelsen  7.29M  3.22G  3.34M   488K 20150423 4 min 9 s
#                                 how_to_read_music_tim_hansen  8.54M  3.23G  4.28M   487K 20130718 5 min 23 s
#                       history_vs_vladimir_lenin_alex_gendler  15.9M  3.24G  3.80M   486K 20140407 6 min 42 s
#           the_scientific_origins_of_the_minotaur_matt_kaplan  10.4M  3.25G  3.31M   485K 20150720 4 min 40 s
#             can_you_solve_the_death_race_riddle_alex_gendler  13.6M  3.26G   969K   485K 20200303 5 min 50 s
#                                   string_theory_brian_greene  37.8M  3.30G  4.25M   484K 20130809 19 min 9 s
#            the_art_forger_who_tricked_the_nazis_noah_charney  10.4M  3.31G   967K   483K 20200406 5 min 16 s
#                      the_genius_of_marie_curie_shohini_ghose  9.06M  3.32G  2.35M   482K 20170608 5 min 3 s
#                        your_body_vs_implants_kaitlyn_sadtler  11.4M  3.33G  1.41M   480K 20190617 4 min 39 s
#                 history_vs_christopher_columbus_alex_gendler  10.0M  3.34G  3.28M   480K 20141013 5 min 54 s
# what_really_happens_to_the_plastic_you_throw_away_emma_bryce  6.68M  3.35G  3.28M   480K 20150421 4 min 6 s
# can_you_solve_the_sorting_hat_riddle_dan_katz_and_alex_rosen  20.2M  3.37G   958K   479K 20200901 5 min 59 s
#  how_the_normans_changed_the_history_of_europe_mark_robinson  13.3M  3.38G  1.87M   479K 20180809 5 min 19 s
# exponential_growth_how_folding_paper_can_get_you_to_the_moon  6.30M  3.39G  4.67M   478K 20120419 3 min 48 s
#      the_real_story_behind_archimedes_eureka_armand_d_angour  10.3M  3.40G  3.26M   477K 20150313 4 min 41 s
#            how_does_your_body_process_medicine_celine_valery  9.04M  3.41G  2.32M   475K 20170515 4 min 12 s
#    a_day_in_the_life_of_a_mongolian_queen_anne_f_broadbridge  7.17M  3.41G  1.39M   475K 20190117 4 min 23 s
# why_dont_poisonous_animals_poison_themselves_rebecca_d_tarvi  9.25M  3.42G  1.85M   473K 20180705 5 min 9 s
#       how_the_monkey_king_escaped_the_underworld_shunan_teng  15.4M  3.44G   943K   472K 20200407 4 min 57 s
#                       history_vs_sigmund_freud_todd_dufresne  8.79M  3.44G   943K   471K 20200331 5 min 54 s
#                   the_power_of_the_placebo_effect_emma_bryce  8.45M  3.45G  2.75M   470K 20160404 4 min 37 s
# this_is_sparta_fierce_warriors_of_the_ancient_world_craig_zi  8.43M  3.46G  2.75M   469K 20160308 4 min 27 s
# what_causes_opioid_addiction_and_why_is_it_so_tough_to_comba  19.1M  3.48G   934K   467K 20200507 8 min 21 s
# game_theory_challenge_can_you_predict_human_behavior_lucas_h  5.95M  3.49G   933K   467K 20191105 4 min 58 s
# the_rise_and_fall_of_historys_first_empire_soraya_field_fior  23.9M  3.51G   465K   465K 20201015 5 min 37 s
#                how_fast_is_the_speed_of_thought_seena_mathew  20.8M  3.53G   465K   465K 20201116 5 min 16 s
#      what_is_the_heisenberg_uncertainty_principle_chad_orzel  5.96M  3.54G  3.62M   463K 20140916 4 min 43 s
#                    how_aspirin_was_discovered_krishna_sudhir  11.6M  3.55G  1.81M   463K 20171002 5 min 44 s
#       why_doesnt_anything_stick_to_teflon_ashwini_bharathula  8.67M  3.55G  2.26M   462K 20161213 4 min 44 s
#         the_evolution_of_animal_genitalia_menno_schilthuizen  13.2M  3.57G  2.25M   462K 20170424 5 min 35 s
#                  how_fast_can_a_vaccine_be_made_dan_kwartler  20.4M  3.59G   918K   459K 20200615 5 min 51 s
#                     how_do_personality_tests_work_merve_emre  19.5M  3.61G   459K   459K 20201222 4 min 56 s
# why_do_competitors_open_their_stores_next_to_one_another_jac  8.49M  3.62G  4.47M   458K 20121001 4 min 6 s
# the_incredible_history_of_china_s_terracotta_warriors_megan_  7.41M  3.62G  3.13M   457K 20150630 4 min 31 s
#                why_is_meningitis_so_dangerous_melvin_sanicas  9.77M  3.63G  1.34M   457K 20181119 4 min 53 s
#                      ugly_history_witch_hunts_brian_a_pavlac  13.9M  3.65G  1.33M   454K 20190611 5 min 25 s
#                               is_telekinesis_real_emma_bryce  8.68M  3.65G  3.54M   453K 20140930 5 min 22 s
#                        what_is_dyslexia_kelli_sandman_hurley  7.51M  3.66G  3.97M   451K 20130715 4 min 34 s
#  can_you_outsmart_a_troll_by_thinking_like_one_claire_wardle  18.4M  3.68G   451K   451K 20201029 5 min 0 s
#          why_should_you_read_james_joyce_s_ulysses_sam_slote  18.6M  3.70G  1.76M   451K 20171024 5 min 58 s
# dna_hot_pockets_the_longest_word_ever_crash_course_biology_1  44.7M  3.74G  4.39M   449K 20120409 14 min 7 s
# titan_of_terror_the_dark_imagination_of_h_p_lovecraft_silvia  8.52M  3.75G  1.31M   448K 20190423 4 min 46 s
# the_surprising_reason_you_feel_awful_when_you_re_sick_marco_  7.36M  3.76G  2.60M   443K 20160419 5 min 0 s
#         can_you_solve_the_rebel_supplies_riddle_alex_gendler  8.80M  3.77G  1.72M   441K 20180910 5 min 17 s
# what_machiavellian_really_means_pazit_cahlon_and_alex_gendle  7.85M  3.77G  1.29M   441K 20190325 5 min 9 s
# ethical_dilemma_the_burger_murders_george_siedel_and_christi  21.9M  3.79G   881K   441K 20200728 5 min 45 s
#        the_surprising_reasons_animals_play_dead_tierney_thys  7.38M  3.80G  1.71M   437K 20180416 4 min 46 s
#    the_aztec_myth_of_the_unlikeliest_sun_god_kay_almere_read  12.1M  3.81G  1.28M   436K 20190509 4 min 12 s
# jellyfish_predate_dinosaurs_how_have_they_survived_so_long_d  11.0M  3.82G  2.13M   436K 20170328 5 min 25 s
#  why_is_herodotus_called_the_father_of_history_mark_robinson  7.87M  3.83G  1.68M   430K 20171211 5 min 2 s
#       how_do_viruses_jump_from_animals_to_humans_ben_longdon  10.4M  3.84G  1.26M   430K 20190808 5 min 4 s
#                      why_is_glass_transparent_mark_miodownik  6.71M  3.85G  3.35M   429K 20140204 4 min 7 s
#         history_vs_henry_viii_mark_robinson_and_alex_gendler  7.82M  3.86G  1.25M   427K 20181112 5 min 24 s
# would_you_opt_for_a_life_with_no_pain_hayley_levitt_and_beth  6.52M  3.86G  2.50M   426K 20151117 4 min 9 s
#    what_is_mccarthyism_and_how_did_it_happen_ellen_schrecker  9.78M  3.87G  2.08M   425K 20170314 5 min 42 s
# which_bag_should_you_use_luka_seamus_wright_and_imogen_ellen  14.6M  3.89G   423K   423K 20201119 4 min 52 s
#  exploring_other_dimensions_alex_rosenthal_and_george_zaidan  8.57M  3.89G  3.69M   420K 20130717 4 min 48 s
#                        are_ghost_ships_real_peter_b_campbell  11.7M  3.91G  2.05M   419K 20170228 5 min 0 s
#  how_do_nuclear_power_plants_work_m_v_ramana_and_sajan_saini  11.5M  3.92G  2.02M   414K 20170508 8 min 6 s
#                        history_vs_richard_nixon_alex_gendler  9.98M  3.93G  2.83M   413K 20150212 5 min 39 s
#                 what_happens_during_a_stroke_vaibhav_goswami  10.5M  3.94G  1.61M   412K 20180201 4 min 59 s
#                         is_time_travel_possible_colin_stuart  11.5M  3.95G  3.21M   411K 20131021 5 min 3 s
#        what_happens_when_you_remove_the_hippocampus_sam_kean  7.69M  3.96G  3.21M   411K 20140826 5 min 25 s
#          why_do_airlines_sell_too_many_tickets_nina_klietsch  6.11M  3.96G  2.00M   410K 20161220 4 min 59 s
# how_many_ways_are_there_to_prove_the_pythagorean_theorem_bet  7.39M  3.97G  2.00M   410K 20170911 5 min 16 s
# a_day_in_the_life_of_a_teenage_samurai_constantine_n_vaporis  36.1M  4.00G   817K   408K 20200622 5 min 30 s
#                  can_a_black_hole_be_destroyed_fabio_pacucci  16.3M  4.02G  1.19M   406K 20190516 5 min 6 s
# what_really_happened_to_the_library_of_alexandria_elizabeth_  8.42M  4.03G  1.58M   406K 20180814 4 min 52 s
#    is_there_any_truth_to_the_king_arthur_legends_alan_lupack  15.0M  4.04G  1.58M   405K 20180911 5 min 42 s
#                         the_history_of_marriage_alex_gendler  8.24M  4.05G  3.17M   405K 20140213 4 min 43 s
#               the_hidden_treasures_of_timbuktu_elizabeth_cox  20.6M  4.07G   402K   402K 20201022 5 min 34 s
#          the_wacky_history_of_cell_theory_lauren_royal_woods  15.4M  4.09G  3.90M   400K 20120604 6 min 11 s
#                 will_we_ever_be_able_to_teleport_sajan_saini  17.3M  4.10G  1.95M   399K 20170731 5 min 37 s
#          how_to_make_your_writing_suspenseful_victoria_smith  8.44M  4.11G  1.55M   397K 20171031 4 min 35 s
#                        the_science_of_spiciness_rose_eveleth  6.03M  4.12G  3.09M   396K 20140310 3 min 54 s
#                 can_you_solve_the_honeybee_riddle_dan_finkel  17.3M  4.13G   788K   394K 20200730 5 min 32 s
#             the_taino_myth_of_the_cursed_creator_bill_keegan  10.9M  4.14G   783K   392K 20191104 3 min 45 s
#   what_percentage_of_your_brain_do_you_use_richard_e_cytowic  8.93M  4.15G  3.05M   391K 20140130 5 min 15 s
#           the_hidden_meanings_of_yin_and_yang_john_bellaimey  13.5M  4.17G  3.43M   390K 20130802 4 min 9 s
# can_you_survive_nuclear_fallout_brooke_buddemeier_and_jessic  8.90M  4.18G  1.14M   390K 20190108 5 min 24 s
# the_myth_of_the_sampo_an_infinite_source_of_fortune_and_gree  11.9M  4.19G  1.14M   390K 20190923 5 min 15 s
#           where_do_math_symbols_come_from_john_david_walters  10.6M  4.20G  1.52M   389K 20171030 4 min 29 s
#              can_you_solve_the_alien_probe_riddle_dan_finkel  8.42M  4.21G  1.52M   389K 20180924 5 min 8 s
#         football_physics_the_impossible_free_kick_erez_garty  7.58M  4.21G  2.66M   389K 20150615 3 min 32 s
#      check_your_intuition_the_birthday_problem_david_knuffke  13.3M  4.23G  1.87M   383K 20170504 5 min 6 s
# are_you_a_body_with_a_mind_or_a_mind_with_a_body_maryam_alim  10.6M  4.24G  1.87M   382K 20170925 6 min 9 s
#         the_myth_of_jason_and_the_argonauts_iseult_gillespie  13.5M  4.25G  1.12M   382K 20190827 5 min 14 s
#                      the_magic_of_vedic_math_gaurav_tekriwal  19.2M  4.27G  3.36M   382K 20130416 9 min 44 s
# can_100_renewable_energy_power_the_world_federico_rosei_and_  9.36M  4.28G  1.49M   382K 20171207 5 min 54 s
#                 the_science_of_skin_color_angela_koine_flynn  9.01M  4.29G  2.23M   381K 20160216 4 min 53 s
#      the_physics_of_the_hardest_move_in_ballet_arleen_sugano  7.90M  4.29G  2.23M   380K 20160322 4 min 16 s
#         why_do_we_harvest_horseshoe_crab_blood_elizabeth_cox  7.50M  4.30G  1.85M   378K 20170921 4 min 45 s
# what_happens_if_you_cut_down_all_of_a_city_s_trees_stefan_al  14.9M  4.32G   756K   378K 20200424 5 min 25 s
# a_day_in_the_life_of_an_ancient_babylonian_business_mogul_so  22.4M  4.34G   378K   378K 20210107 4 min 46 s
#                    how_computer_memory_works_kanawat_senanan  13.2M  4.35G  2.21M   377K 20160510 5 min 4 s
#                how_do_investors_choose_stocks_richard_coffin  15.1M  4.37G   376K   376K 20201110 5 min 1 s
#                        what_causes_constipation_heba_shaheed  5.30M  4.37G  1.46M   375K 20180507 3 min 32 s
#                      the_life_cycle_of_a_t_shirt_angel_chang  12.3M  4.38G  1.82M   373K 20170905 6 min 3 s
# how_a_single_celled_organism_almost_wiped_out_life_on_earth_  7.87M  4.39G  2.19M   373K 20160811 4 min 13 s
#                 three_ways_the_universe_could_end_venus_keus  7.53M  4.40G  1.09M   373K 20190219 4 min 46 s
#                 how_to_spot_a_misleading_graph_lea_gaslowitz  8.34M  4.41G  1.82M   372K 20170706 4 min 9 s
# how_one_scientist_averted_a_national_health_crisis_andrea_to  13.0M  4.42G  1.45M   372K 20180607 5 min 31 s
#       why_should_you_read_the_handmaid_s_tale_naomi_r_mercer  11.2M  4.43G  1.45M   372K 20180308 5 min 4 s
#             the_princess_who_rewrote_history_leonora_neville  7.54M  4.44G  1.09M   372K 20181022 4 min 57 s
#          why_should_you_read_virginia_woolf_iseult_gillespie  15.7M  4.45G  1.45M   371K 20171005 6 min 2 s
#                        why_can_t_some_birds_fly_gillian_gibb  6.71M  4.46G  1.08M   367K 20181018 4 min 31 s
#            a_brief_history_of_banned_numbers_alessandra_king  7.66M  4.47G  1.79M   366K 20170926 4 min 42 s
#                   the_worlds_largest_organism_alex_rosenthal  23.3M  4.49G   366K   366K 20201207 6 min 27 s
#            the_wild_world_of_carnivorous_plants_kenny_coogan  7.90M  4.50G  1.07M   366K 20190411 5 min 10 s
#       why_do_you_get_a_fever_when_you_re_sick_christian_moro  19.7M  4.52G   366K   366K 20201112 5 min 37 s
#                         how_do_ventilators_work_alex_gendler  12.1M  4.53G   731K   365K 20200521 5 min 41 s
#                  why_is_mount_everest_so_tall_michele_koppes  7.35M  4.53G  2.13M   364K 20160407 4 min 52 s
#                           how_smart_are_dolphins_lori_marino  9.95M  4.54G  2.49M   364K 20150831 4 min 50 s
#            vampires_folklore_fantasy_and_fact_michael_molina  11.5M  4.56G  2.84M   364K 20131029 6 min 56 s
#            how_does_your_body_know_you_re_full_hilary_coller  8.23M  4.56G  1.42M   364K 20171113 4 min 33 s
#          sex_determination_more_complicated_than_you_thought  17.4M  4.58G  3.54M   363K 20120423 5 min 45 s
#                            how_do_crystals_work_graham_baird  12.4M  4.59G  1.06M   362K 20190618 5 min 6 s
# the_japanese_folktale_of_the_selfish_scholar_iseult_gillespi  14.7M  4.61G   724K   362K 20200914 4 min 59 s
#                 human_sperm_vs_the_sperm_whale_aatish_bhatia  10.1M  4.62G  3.16M   359K 20130923 4 min 17 s
# the_imaginary_king_who_changed_the_real_world_matteo_salvado  12.1M  4.63G   715K   357K 20200319 5 min 33 s
#                            the_maya_myth_of_the_morning_star  8.79M  4.64G   713K   356K 20191021 4 min 35 s
#               the_wicked_wit_of_jane_austen_iseult_gillespie  15.8M  4.65G  1.04M   356K 20190321 5 min 0 s
# why_should_you_read_dantes_divine_comedy_sheila_marie_orfano  12.2M  4.67G   712K   356K 20191010 5 min 9 s
#           poison_vs_venom_what_s_the_difference_rose_eveleth  7.73M  4.67G  2.78M   356K 20140220 3 min 55 s
# building_the_world_s_largest_and_most_controversial_power_pl  22.3M  4.69G   354K   354K 20201210 5 min 37 s
#  how_to_use_rhetoric_to_get_what_you_want_camille_a_langston  6.38M  4.70G  2.07M   354K 20160920 4 min 29 s
#                                why_do_we_hiccup_john_cameron  10.1M  4.71G  2.07M   354K 20160728 4 min 49 s
#       why_are_we_so_attached_to_our_things_christian_jarrett  8.22M  4.72G  1.72M   353K 20161227 4 min 34 s
#                how_the_heart_actually_pumps_blood_edmond_hui  6.19M  4.72G  2.75M   353K 20140520 4 min 27 s
#               what_is_deja_vu_what_is_deja_vu_michael_molina  5.50M  4.73G  3.09M   352K 20130828 3 min 54 s
#   what_happened_when_we_all_stopped_narrated_by_jane_goodall  6.08M  4.74G   703K   351K 20200604 3 min 15 s
#            the_strange_case_of_the_cyclops_sheep_tien_nguyen  6.87M  4.74G  1.37M   351K 20171003 4 min 40 s
# can_you_outsmart_the_fallacy_that_fooled_a_generation_of_doc  19.7M  4.76G   700K   350K 20200810 5 min 30 s
#                                claws_vs_nails_matthew_borths  7.38M  4.77G   700K   350K 20191029 5 min 10 s
#                              how_smart_are_orangutans_lu_gao  6.85M  4.78G  2.05M   349K 20160830 4 min 32 s
#                     the_prison_break_think_like_a_coder_ep_1  14.0M  4.79G  1.02M   349K 20190930 6 min 50 s
#                    why_do_blood_types_matter_natalie_s_hodge  9.45M  4.80G  2.37M   347K 20150629 4 min 41 s
#           a_day_in_the_life_of_a_celtic_druid_philip_freeman  15.0M  4.81G  1.02M   347K 20190917 4 min 30 s
#                   the_arctic_vs_the_antarctic_camille_seaman  6.20M  4.82G  3.05M   347K 20130819 4 min 24 s
#               what_is_zeno_s_dichotomy_paradox_colm_kelleher  8.55M  4.83G  3.04M   346K 20130415 4 min 11 s
# how_does_the_nobel_peace_prize_work_adeline_cuvelier_and_tor  11.7M  4.84G  1.69M   346K 20161006 6 min 14 s
# ...
#                     we_need_better_drugs_now_francis_collins  25.9M  22.4G  8.16K    927 20130830 14 min 40 s
#                      trusting_the_ensemble_charles_hazlewood  52.0M  22.5G  8.14K    925 20130809 19 min 36 s
#                 what_fear_can_teach_us_karen_thompson_walker  25.4M  22.5G  8.11K    922 20130517 11 min 30 s
#      what_we_re_learning_from_online_education_daphne_koller  40.9M  22.5G  7.91K    900 20130614 20 min 40 s
#           what_we_re_learning_from_5000_brains_read_montague  26.2M  22.5G  7.91K    899 20130531 13 min 23 s
#     weaving_narratives_in_museum_galleries_thomas_p_campbell  34.8M  22.6G  7.91K    899 20130511 16 min 36 s
#                   mining_minerals_from_seawater_damian_palin  4.76M  22.6G  7.77K    884 20130705 3 min 1 s
#           how_poachers_became_caretakers_john_kasaona_glitch  28.4M  22.6G  7.64K    869 20130310 15 min 46 s
#                         shape_shifting_dinosaurs_jack_horner  36.1M  22.6G  7.35K    836 20130815 18 min 22 s
#                        texting_that_saves_lives_nancy_lublin  12.3M  22.7G  7.30K    830 20130712 5 min 24 s
#                            click_your_fortune_episode_3_demo  5.18M  22.7G  7.29K    829 20130807 3 min 31 s
#                      why_i_hold_on_to_my_grandmother_s_tales  13.0M  22.7G  3.21K    820 20180117 7 min 8 s
#           obesity_hunger_1_global_food_issue_ellen_gustafson  15.4M  22.7G  7.16K    814 20130801 16 min 34 s
#          a_broken_body_isn_t_a_broken_person_janine_shepherd  34.8M  22.7G  7.08K    805 20130528 18 min 57 s
#        the_case_for_collaborative_consumption_rachel_botsman  29.1M  22.8G  6.97K    792 20130717 16 min 34 s
#           ultrasound_surgery_healing_without_cuts_yoav_medan  30.7M  22.8G  6.94K    790 20130719 16 min 13 s
#                how_to_defend_earth_from_asteroids_phil_plait  22.7M  22.8G  6.94K    789 20130808 14 min 16 s
#                       let_s_teach_kids_to_code_mitch_resnick  29.1M  22.8G  6.92K    787 20130424 16 min 48 s
#              a_whistleblower_you_haven_t_heard_geert_chatrou  21.9M  22.9G  6.92K    786 20130815 11 min 56 s
#                            a_doctor_s_touch_abraham_verghese  38.3M  22.9G  6.88K    782 20130816 18 min 32 s
#                    how_we_found_the_giant_squid_edith_widder  15.2M  22.9G  6.76K    769 20130830 8 min 38 s
#                   a_plane_you_can_drive_anna_mracek_dietrich  19.5M  22.9G  6.75K    767 20130809 9 min 37 s
#                a_civil_response_to_violence_emiliano_salinas  20.4M  22.9G  6.66K    757 20130808 12 min 17 s
#      let_s_transform_energy_with_natural_gas_t_boone_pickens  34.6M  23.0G  6.65K    756 20130719 19 min 42 s
#                 pool_medical_patents_save_lives_ellen_t_hoen  18.6M  23.0G  6.63K    754 20130428 11 min 16 s
#                          how_to_buy_happiness_michael_norton  17.8M  23.0G  6.61K    752 20130821 10 min 58 s
#                       re_examining_the_remix_lawrence_lessig  28.9M  23.0G  6.58K    748 20130801 18 min 45 s
#               the_flavors_of_life_through_the_eyes_of_a_chef  17.4M  23.1G  2.91K    744 20171130 6 min 39 s
# what_nonprofits_can_learn_from_coca_cola_melinda_french_gate  33.8M  23.1G  6.50K    739 20130815 16 min 28 s
#                             kids_need_structure_colin_powell  33.4M  23.1G  6.48K    737 20130401 17 min 46 s
#            a_mini_robot_powered_by_your_phone_keller_rinaudo  12.0M  23.1G  6.42K    730 20130823 5 min 54 s
#                          meet_the_water_canary_sonaar_luthra  5.73M  23.1G  6.40K    728 20130726 3 min 37 s
#                      the_right_time_to_second_guess_yourself  22.4M  23.2G  3.55K    726 20170810 11 min 56 s
#                      how_you_can_help_fight_pediatric_cancer  14.4M  23.2G  3.51K    718 20170608 8 min 6 s
#        the_future_race_car_150mph_and_no_driver_chris_gerdes  29.8M  23.2G  6.30K    717 20130829 10 min 47 s
#      a_universal_translator_for_surgeons_steven_schwaitzberg  19.3M  23.2G  6.27K    713 20130519 11 min 41 s
#                a_vision_of_crimes_in_the_future_marc_goodman  20.6M  23.2G  6.25K    711 20130628 8 min 44 s
#  how_do_you_save_a_shark_you_know_nothing_about_simon_berrow  35.7M  23.3G  6.17K    701 20130626 16 min 46 s
#     let_s_put_birth_control_back_on_the_agenda_melinda_gates  55.2M  23.3G  6.04K    687 20130605 25 min 36 s
#              a_father_daughter_dance_in_prison_angela_patton  22.3M  23.4G  5.37K    686 20131211 8 min 48 s
#          the_good_news_on_poverty_yes_there_s_good_news_bono  24.9M  23.4G  5.96K    678 20130823 13 min 57 s
#            what_we_learn_before_we_re_born_annie_murphy_paul  21.3M  23.4G  5.95K    676 20130809 8 min 44 s
#   sometimes_it_s_good_to_give_up_the_driver_s_seat_baba_shiv  24.8M  23.4G  5.89K    670 20130501 9 min 47 s
# unlock_the_intelligence_passion_greatness_of_girls_leymah_gb  44.7M  23.5G  5.81K    661 20130712 20 min 28 s
#                     1000_tedtalks_6_words_sebastian_wernicke  13.3M  23.5G  5.75K    654 20130815 7 min 33 s
#                      a_prosthetic_arm_that_feels_todd_kuiken  38.2M  23.5G  5.75K    653 20130809 18 min 51 s
#                   my_friend_richard_feynman_leonard_susskind  27.6M  23.5G  5.64K    641 20130815 14 min 41 s
#                             a_child_of_the_state_lemn_sissay  29.0M  23.6G  4.99K    638 20131211 15 min 36 s
#         experiments_that_hint_of_longer_lives_cynthia_kenyon  31.1M  23.6G  5.51K    626 20130809 16 min 23 s
#                using_nature_to_grow_batteries_angela_belcher  19.7M  23.6G  5.51K    626 20130815 10 min 25 s
#          could_the_sun_be_good_for_your_heart_richard_weller  23.7M  23.6G  5.45K    620 20130325 12 min 59 s
#               energy_from_floating_algae_pods_jonathan_trent  30.6M  23.7G  5.41K    615 20130607 14 min 45 s
#                       crowdsource_your_health_lucien_engelen  14.6M  23.7G  5.35K    609 20130815 6 min 12 s
#                           before_i_die_i_want_to_candy_chang  11.3M  23.7G  5.31K    604 20130614 6 min 19 s
#                                      where_is_home_pico_iyer  31.2M  23.7G  5.30K    603 20130823 14 min 4 s
#                    the_dance_of_the_dung_beetle_marcus_byrne  35.9M  23.8G  5.28K    600 20130429 17 min 8 s
#                   lessons_from_death_row_inmates_david_r_dow  32.2M  23.8G  5.19K    590 20130821 18 min 16 s
#          mental_health_for_all_by_involving_all_vikram_patel  32.5M  23.8G  5.11K    581 20130607 12 min 22 s
#               how_healthy_living_nearly_killed_me_a_j_jacobs  14.8M  23.8G  5.05K    574 20130726 8 min 42 s
#                         how_do_we_heal_medicine_atul_gawande  33.9M  23.9G  5.02K    570 20130419 19 min 19 s
# what_s_a_snollygoster_a_short_lesson_in_political_speak_mark  15.6M  23.9G  4.99K    567 20130410 6 min 39 s
# science_is_for_everyone_kids_included_beau_lotto_and_amy_o_t  37.9M  23.9G  4.91K    558 20130524 15 min 25 s
#                       how_to_topple_a_dictator_srdja_popovic  37.9M  24.0G  4.86K    553 20130815 12 min 3 s
#               let_s_prepare_for_our_new_climate_vicki_arroyo  21.3M  24.0G  4.86K    553 20130524 10 min 38 s
# parkinson_s_depression_and_the_switch_that_might_turn_them_o  24.7M  24.0G  4.66K    530 20130612 15 min 34 s
#       gaming_to_re_engage_boys_in_learning_ali_carr_chellman  24.5M  24.0G  4.60K    522 20130815 12 min 30 s
#               neuroscience_game_theory_monkeys_colin_camerer  21.7M  24.1G  4.56K    519 20130619 13 min 49 s
#                 the_voice_of_the_natural_world_bernie_krause  34.1M  24.1G  4.48K    509 20130816 14 min 51 s
# the_single_biggest_health_threat_women_face_noel_bairey_merz  31.5M  24.1G  4.45K    505 20130506 15 min 59 s
# a_choreographer_s_creative_process_in_real_time_wayne_mcgreg  43.7M  24.2G  4.44K    505 20130607 15 min 18 s
# we_the_people_and_the_republic_we_must_reclaim_lawrence_less  34.1M  24.2G  4.40K    500 20130823 18 min 22 s
#                        how_to_expose_the_corrupt_peter_eigen  26.9M  24.2G  4.38K    498 20130725 16 min 12 s
#         michael_green_why_we_should_build_wooden_skyscrapers  23.7M  24.2G  4.38K    498 20130816 12 min 25 s
#                   inside_the_egyptian_revolution_wael_ghonim  26.8M  24.3G  4.37K    497 20130725 10 min 7 s
#    a_clean_energy_proposal_race_to_the_top_jennifer_granholm  27.2M  24.3G  4.37K    496 20130830 12 min 41 s
#      how_i_taught_rats_to_sniff_out_land_mines_bart_weetjens  22.5M  24.3G  4.26K    484 20130801 12 min 11 s
#              the_shared_experience_of_absurdity_charlie_todd  32.2M  24.4G  4.23K    481 20130808 12 min 4 s
# could_tissue_engineering_mean_personalized_medicine_nina_tan  10.3M  24.4G  4.19K    476 20130517 6 min 19 s
#                                  my_immigration_story_tan_le  26.7M  24.4G  4.08K    463 20130815 12 min 16 s
#                    older_people_are_happier_laura_carstensen  20.9M  24.4G  4.04K    459 20130821 11 min 38 s
#                           we_can_recycle_plastic_mike_biddle  22.4M  24.4G  3.97K    451 20130809 10 min 58 s
#                           print_your_own_medicine_lee_cronin  5.44M  24.4G  3.93K    447 20130510 3 min 6 s
#                 how_to_look_inside_the_brain_carl_schoonover  9.04M  24.4G  3.89K    442 20130712 4 min 59 s
#               building_unimaginable_shapes_michael_hansmeyer  24.9M  24.5G  3.83K    436 20130621 11 min 7 s
# how_to_step_up_in_the_face_of_disaster_caitria_morgan_o_neil  19.7M  24.5G  3.77K    428 20130829 9 min 23 s
#         a_prosthetic_eye_to_treat_blindness_sheila_nirenberg  19.1M  24.5G  3.66K    416 20130726 10 min 5 s
#                             embrace_the_remix_kirby_ferguson  17.5M  24.5G  3.52K    400 20130510 9 min 42 s
#                        advice_to_young_scientists_e_o_wilson  27.0M  24.6G  3.44K    391 20130705 14 min 56 s
#                the_strange_politics_of_disgust_david_pizarro  27.5M  24.6G  3.37K    383 20130408 14 min 2 s
#                          what_s_left_to_explore_nathan_wolfe  14.1M  24.6G  3.31K    377 20130507 7 min 10 s
#   what_if_our_healthcare_system_kept_us_healthy_rebecca_onie  29.6M  24.6G  3.31K    376 20130705 16 min 34 s
#       visualizing_the_medical_data_explosion_anders_ynnerman  25.7M  24.6G  3.26K    371 20130710 16 min 34 s
#                    the_100000_student_classroom_peter_norvig  11.4M  24.7G  3.22K    366 20130705 6 min 11 s
#      a_teacher_growing_green_in_the_south_bronx_stephen_ritz  31.5M  24.7G  3.21K    365 20130829 13 min 42 s
#                            tracking_the_trackers_gary_kovacs  11.2M  24.7G  3.21K    364 20130426 6 min 39 s
#                   fighting_with_non_violence_scilla_elworthy  13.8M  24.7G  3.19K    362 20130619 8 min 44 s
#        why_architects_need_to_use_their_ears_julian_treasure  16.5M  24.7G  3.11K    353 20130531 9 min 51 s
#              the_secret_lives_of_paintings_maurizio_seracini  21.8M  24.8G  2.91K    331 20130524 12 min 34 s
#                         what_s_your_200_year_plan_raghava_kk  20.8M  24.8G  2.92K    331 20130829 10 min 58 s
#                          be_an_artist_right_now_young_ha_kim  38.2M  24.8G  2.85K    324 20130612 16 min 57 s
#                                  life_s_third_act_jane_fonda  26.0M  24.8G  2.85K    324 20130815 11 min 20 s
#                        making_sense_of_maps_aris_venetikidis  36.0M  24.9G  2.82K    321 20130529 16 min 35 s
#             fighting_a_contagious_cancer_elizabeth_murchison  26.7M  24.9G  2.77K    314 20130816 13 min 3 s
#    tracking_ancient_diseases_using_plaque_christina_warinner  9.05M  24.9G  2.74K    311 20130712 5 min 31 s
# experiments_that_point_to_a_new_understanding_of_cancer_mina  36.7M  24.9G  2.73K    310 20130628 16 min 17 s
#              cloudy_with_a_chance_of_joy_gavin_pretor_pinney  18.9M  25.0G  2.73K    310 20130816 10 min 57 s
#                design_for_people_not_awards_timothy_prestero  20.8M  25.0G  2.72K    309 20130829 11 min 4 s
#                           the_art_of_creating_awe_rob_legato  50.3M  25.0G  2.56K    291 20130614 16 min 27 s
#               can_democracy_exist_without_trust_ivan_krastev  27.9M  25.1G  2.53K    287 20130510 14 min 4 s
#        the_promise_of_research_with_stem_cells_susan_solomon  24.4M  25.1G  2.42K    275 20130607 15 min 31 s
#                         a_census_of_the_ocean_paul_snelgrove  27.5M  25.1G  2.39K    271 20130719 16 min 47 s
#                finding_life_we_can_t_imagine_christoph_adami  41.4M  25.1G  2.38K    270 20130808 18 min 51 s
#                   your_phone_company_is_watching_malte_spitz  27.3M  25.2G  2.32K    264 20130621 10 min 10 s
#            welcome_to_the_genomic_revolution_richard_resnick  20.1M  25.2G  2.32K    263 20130703 11 min 2 s
#                          technology_s_epic_story_kevin_kelly  31.7M  25.2G  2.28K    259 20130725 16 min 32 s
#             freeing_energy_from_the_grid_justin_hall_tipping  30.8M  25.3G  2.21K    251 20130809 12 min 45 s
#                    excuse_me_may_i_rent_your_car_robin_chase  31.3M  25.3G  2.14K    243 20130517 12 min 24 s
#                  the_economic_injustice_of_plastic_van_jones  41.7M  25.3G  2.09K    238 20130808 17 min 33 s
#   how_open_data_is_changing_international_aid_sanjay_pradhan  31.8M  25.4G  2.09K    237 20130517 15 min 20 s
#                    a_girl_who_demanded_school_kakenya_ntaiya  44.2M  25.4G  2.06K    234 20130513 15 min 16 s
#                   demand_a_fair_trade_cell_phone_bandi_mbubi  15.2M  25.4G  2.03K    230 20130829 9 min 21 s
#          what_your_designs_say_about_you_sebastian_deterding  18.0M  25.4G  1.95K    221 20130821 12 min 20 s
#             demand_a_more_open_source_government_beth_noveck  41.4M  25.5G  1.91K    217 20130607 17 min 23 s
#                  a_story_about_knots_and_surgeons_ed_gavagan  24.7M  25.5G  1.84K    209 20130531 12 min 21 s
#                    let_s_pool_our_medical_data_john_wilbanks  32.1M  25.5G  1.75K    198 20130524 16 min 25 s
#          a_lab_the_size_of_a_postage_stamp_george_whitesides  26.3M  25.6G  1.65K    187 20130808 16 min 16 s
#          a_test_for_parkinson_s_with_a_phone_call_max_little  12.5M  25.6G  1.65K    187 20130614 6 min 3 s
#      ethical_riddles_in_hiv_research_boghuma_kabisen_titanji  20.8M  25.6G  1.64K    186 20130605 11 min 10 s
#              massive_scale_online_collaboration_luis_von_ahn  32.2M  25.6G  1.61K    183 20130808 16 min 39 s
#              a_short_intro_to_the_studio_school_geoff_mulgan  8.79M  25.6G  1.49K    169 20130816 6 min 16 s
#        3_stories_of_local_eco_entrepreneurship_majora_carter  27.2M  25.7G  1.46K    165 20130725 16 min 34 s
#                          put_a_value_on_nature_pavan_sukhdev  31.9M  25.7G  1.45K    165 20130726 16 min 30 s
#                                how_to_stop_torture_karen_tse  20.1M  25.7G  1.32K    150 20130809 8 min 44 s
# how_cyberattacks_threaten_real_world_peace_guy_philippe_gold  13.5M  25.7G  1.31K    149 20130808 9 min 23 s
#            the_day_i_turned_down_tim_berners_lee_ian_ritchie  10.7M  25.7G  1.27K    144 20130809 5 min 41 s
# women_entrepreneurs_example_not_exception_gayle_tzemach_lemm  28.7M  25.8G  1.25K    142 20130815 13 min 16 s
#                    the_arts_festival_revolution_david_binder  17.0M  25.8G  1.21K    137 20130517 9 min 4 s
#                      filming_democracy_in_ghana_jarreth_merz  18.0M  25.8G  1.08K    122 20130809 8 min 36 s
#                     there_are_no_scraps_of_men_alberto_cairo  36.4M  25.8G  1.07K    121 20130815 19 min 2 s
#                an_unexpected_place_of_healing_ramona_pierson  33.8M  25.9G  1.01K    114 20130815 11 min 12 s
#                       digital_humanitarianism_paul_conneally  17.6M  25.9G  0.99K    112 20130626 10 min 57 s
#               the_economic_case_for_preschool_timothy_bartik  31.1M  25.9G    706   78.0 20130815 15 min 48 s
#           let_s_crowdsource_the_world_s_goals_jamie_drummond  26.6M  25.9G    687   76.0 20130628 12 min 10 s
#                     how_do_pain_relievers_work_george_zaidan  8.16M  25.9G   0.00   1.00          4 min 13 s
#              the_coming_neurological_epidemic_gregory_petsko  5.35M  25.9G   0.00   1.00          3 min 50 s

# %% [markdown]
# * Now determine the video ID's that we want in our new zim

# %%
print('We will include videos with views_per_year greater than %s'%boundary_views_per_year)
wanted_ids = []
sql = 'SELECT yt_id, title from video_info where views_per_year > ?'
db.c.execute(sql,[boundary_views_per_year,])
rows = db.c.fetchall()
for row in rows:
    wanted_ids.append(row['yt_id'])

with open(HOME + '/zimtest/' + PROJECT_NAME + '/wanted_list.csv','w') as fp:
    for row in rows:
        fp.write('%s,%s\n'%(row['yt_id'],row['title'],))
# Out:
# We will include videos with views_per_year greater than 128020

# %% [markdown]
# * Now let's start building up the output directory

# %%
import shutil
# copy the default top level directories (these were in the zim's "-" directory )
#cpy_dirs = ['assets','cache','channels']
cpy_dirs = ['assets','cache','channels']
for d in cpy_dirs:
    shutil.rmtree(os.path.join(OUTPUT_DIR,d),ignore_errors=True)
    os.makedirs(os.path.join(OUTPUT_DIR,d))
    src = os.path.join(PROJECT_DIR,d)
    dest = os.path.join(OUTPUT_DIR,d)
    shutil.copytree(src,dest,dirs_exist_ok=True, symlinks=True)

# %%
# Copy the videos selected by the wanted_ids list to output file
import shutil
for f in wanted_ids:
    if not os.path.isdir(os.path.join(OUTPUT_DIR,'videos',f)):
        os.makedirs(os.path.join(OUTPUT_DIR,'videos',f))
    src = os.path.join(PROJECT_DIR,'videos',f)
    dest = os.path.join(OUTPUT_DIR,'videos',f)
    shutil.copytree(src,dest,dirs_exist_ok=True)

# %%
#  Copy the files in the root directory
import shutil
for yt_id in wanted_ids:
    map_index_to_slug = get_zim_data(yt_id)
    if len(map_index_to_slug) > 0:
        title = map_index_to_slug['slug']
        src = os.path.join(PROJECT_DIR,title + '.html')
        dest = OUTPUT_DIR + '/' + title + '.html'
        if os.path.isfile(src) and not os.path.isfile(dest):
            shutil.copyfile(src,dest)
        else:
            print('src:%s'%src)
# Out:
# src:/home/ghunt/zimtest/teded/tree/does_your_vote_count_the_electoral_college_explained_christina_greer.html

# %%
wanted_ids

# %%
src = PROJECT_DIR + '/favicon.jpg'
dest = OUTPUT_DIR 
# !/usr/bin/cp {src} {dest}
src = PROJECT_DIR + '/home.html'
# !/usr/bin/cp {src} {dest}

# %%
# Grab the meta data from the original zim "M" directory 
#   and create a script for zimwriterfs
def get_file_value(path):
    with open(path,'r') as fp:
        
        try:
            return fp.read()
        except:
            return ""
meta_data ={}
meta_file_names = os.listdir(PROJECT_DIR + '/M/')
for f in meta_file_names:
    meta_data[f] = get_file_value(PROJECT_DIR + '/M/' + f)
pprint(meta_data)

# %%
# Write a new mapping from categories to vides (with some removed)
outstr = ''
for cat in zim_category_js:
    outstr += 'var json_%s = [\n'%cat
    for video in range(len(zim_category_js[cat])):
        if zim_category_js[cat][video].get('id','') in wanted_ids:
            outstr += json.dumps(zim_category_js[cat][video],indent=1)
            outstr += ','
    outstr = outstr[:-1]
    outstr += '];\n'
with open(OUTPUT_DIR + '/assets/data.js','w') as fp:
    fp.write(outstr)

# %%
    playlist = 'PLs2auPpToJpb6MeiaKEIpkdSWeBVgvC_p'
    CHANNEL = 'UCljl2cmQMgzlTkeJqJier7g'

# %% [raw]
# # Create a template for a script to run zimwriterfs
# mk_zim_cmd = """
# zimwriterfs --language=eng\
#             --welcome=A/home.html\
#             --favicon=I/favicon.jpg\
#             --title=teded_en_%s\
#             --description=\"TED-Ed Videos from YouTube Channel\"\
#             --creator='Youtube Channel “TED-Ed”'\
#             --publisher=IIAB\
#             --name=TED-Ed\
#              %s %s.zim"""%(PROJECT_NAME,OUTPUT_DIR,PROJECT_NAME)
# with open(HOME + '/zimtest/' + PROJECT_NAME + '-zimwriter-cmd.sh','w') as fp:
#     fp.write(mk_zim_cmd)

# %% [markdown]
# #### Jupyter Lab and OpenZim Environments Conflict
# * The "Youtube2zim" path seems to create functioning ZIMS. But it involves a huge cost in time and patience interacting with the Google API.
# * But it provides a simple model in the 'Run' subroutine of scraper.py. Making a zim is really just a subroutine call.
# * So the current strategy is a pass off the environment variables from the jupyter virtual environment to the youtube2zim virtual environment to "zimming" up the modified/shrunken disk tree.

# %%
# Make a dictionary of the processing environment
new_zim_env = {}
new_zim_env['PROJECT_NAME'] = PROJECT_NAME
new_zim_env['CACHE_DIR'] = CACHE_DIR
new_zim_env['WORKING_DIR'] = WORKING_DIR
new_zim_env['OUTPUT_DIR'] = OUTPUT_DIR
new_zim_env['NEW_ZIM_DIR'] = NEW_ZIM_DIR

pass_baton = {}
pass_baton = new_zim_env.copy()
pass_baton.update(meta_data)
pass_baton['Name'] = 'teded_en_selected'
with open(CACHE_DIR + '/pass_baton.json','w') as fp:
    fp.write(json.dumps(pass_baton,indent=2))
pprint(pass_baton)
# Out:
# {'CACHE_DIR': '/home/ghunt/zimtest/youtube/cache',
#  'Counter': 'application/font-sfnt=6;text/css=6;application/javascript=83;text/plain=8;application/octet-stream=15;text/html=1812;application/x-shockwave-flash=1;text/markdown=1;image/jpeg=647;image/svg+xml=1;application/json=208;image/png=2;video/webm=1811;image/webp=1197',
#  'Creator': 'Youtube Channel “TED-Ed”',
#  'Date': '2021-01-16',
#  'Description': 'TED-Ed’s commitment to creating lessons worth sharing is an '
#                 'extension of TED’s mission of spreading great ideas. Within '
#                 'TED-Ed’s growing library of TED-Ed animations, you will find '
#                 'carefully curated educational videos, many of which represent '
#                 'collaborations between talented educators and animators '
#                 'nominated through the TED-Ed website (ed.ted.com).  Want to '
#                 'suggest an idea for a TED-Ed animation or get involved with '
#                 'TED-Ed? Visit our website at: '
#                 'http://ed.ted.com/get_involved.  Also, consider donating to '
#                 'us on Patreon! By doing so, you directly support our mission '
#                 'and receive some pretty awesome rewards: '
#                 'https://www.patreon.com/teded  For more information on using '
#                 'TED for commercial purposes (e.g. employee learning, in a '
#                 'film, or in an online course), please submit a Media Request '
#                 'using this link: https://media-requests.ted.com/',
#  'IndexLanguage': 'eng',
#  'Language': 'eng',
#  'NEW_ZIM_DIR': '/home/ghunt/zimtest/teded/new-zim',
#  'Name': 'teded_en_selected',
#  'OUTPUT_DIR': '/home/ghunt/zimtest/teded/output_tree',
#  'PROJECT_NAME': 'teded',
#  'Publisher': 'Kiwix',
#  'Scraper': 'youtube2zim 2.1.13',
#  'Tags': '_category:ted;_videos:yes',
#  'Title': 'TED-Ed',
#  'WORKING_DIR': '/home/ghunt/zimtest/teded/working'}
